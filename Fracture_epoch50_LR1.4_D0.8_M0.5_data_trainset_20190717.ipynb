# %%
from __future__ import division, print_function
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
plt.rcParams['image.cmap'] = 'gray'
np.random.seed(98765)

# %%
from tf_unet import image_util
from tf_unet import unet
from tf_unet import util

# %%
prediction_path = "./prediction_3layers_feature32_epoch50_LR1.4_D0.8_M0.5_data_trainset_20190717"
output_path = "./trained_3layers_feature32_epoch50_LR1.4_D0.8_M0.5_data_trainset_20190717"
training_data = image_util.ImageDataProvider("./data_trainset_20190717/*.tif")
# Out:
# Number of files used: 26
# Number of channels: 1
# Number of classes: 2

# %%
i=26 #number of images
x_train, y_train = training_data(i)
print(x_train.shape)

#train_y = y_train[...,1].flatten()
#print(train_y.max())
#train_x = x_train[...,0].flatten()
#print(train_x.max())
# Out:
# (26, 1000, 1000, 1)

# %%
net = unet.Unet(layers=3, features_root=32, channels=1, n_class=2)
trainer = unet.Trainer(net, optimizer="momentum", opt_kwargs=dict(momentum=0.5,learning_rate=1.4,decay_rate=0.8))
#trainer = unet.Trainer(net)
path = trainer.train(training_data, output_path, training_iters=32, epochs=50, 
                     display_step=1, prediction_path=prediction_path)
# Out:
# 2019-07-28 10:53:52,505 Layers 3, features 32, filter size 3x3, pool size: 2x2
# WARNING:tensorflow:From /home/yao/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# 2019-07-28 10:53:52,571 From /home/yao/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/yao/.local/lib/python3.6/site-packages/tf_unet-0.1.2-py3.6.egg/tf_unet/layers.py:39: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# 2019-07-28 10:53:52,593 From /home/yao/.local/lib/python3.6/site-packages/tf_unet-0.1.2-py3.6.egg/tf_unet/layers.py:39: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# 2019-07-28 10:53:53,658 Removing '/home/yao/Downloads/tf_unet-master/demo/prediction_3layers_feature32_epoch50_LR1.4_D0.8_M0.5_data_trainset_20190717'
# 2019-07-28 10:53:53,659 Removing '/home/yao/Downloads/tf_unet-master/demo/trained_3layers_feature32_epoch50_LR1.4_D0.8_M0.5_data_trainset_20190717'
# 2019-07-28 10:53:53,659 Allocating '/home/yao/Downloads/tf_unet-master/demo/prediction_3layers_feature32_epoch50_LR1.4_D0.8_M0.5_data_trainset_20190717'
# 2019-07-28 10:53:53,659 Allocating '/home/yao/Downloads/tf_unet-master/demo/trained_3layers_feature32_epoch50_LR1.4_D0.8_M0.5_data_trainset_20190717'
# 2019-07-28 10:54:16,129 Verification error= 0.0%, loss= 0.6547
# 2019-07-28 10:54:17,009 Start optimization
# 2019-07-28 10:54:34,747 Iter 0, Minibatch Loss= 0.0786, Training Accuracy= 0.9983, Minibatch error= 0.2%
# 2019-07-28 10:54:49,685 Iter 1, Minibatch Loss= 0.0456, Training Accuracy= 0.9973, Minibatch error= 0.3%
# 2019-07-28 10:55:04,659 Iter 2, Minibatch Loss= 0.0769, Training Accuracy= 0.9893, Minibatch error= 1.1%
# 2019-07-28 10:55:19,494 Iter 3, Minibatch Loss= 0.0116, Training Accuracy= 0.9980, Minibatch error= 0.2%
# 2019-07-28 10:55:34,441 Iter 4, Minibatch Loss= 0.0042, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-28 10:55:49,313 Iter 5, Minibatch Loss= 0.0009, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-28 10:56:04,075 Iter 6, Minibatch Loss= 0.0331, Training Accuracy= 0.9930, Minibatch error= 0.7%
# 2019-07-28 10:56:18,788 Iter 7, Minibatch Loss= 0.0036, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-28 10:56:33,796 Iter 8, Minibatch Loss= 0.0436, Training Accuracy= 0.9904, Minibatch error= 1.0%
# 2019-07-28 10:56:48,874 Iter 9, Minibatch Loss= 0.0102, Training Accuracy= 0.9986, Minibatch error= 0.1%
# 2019-07-28 10:57:03,730 Iter 10, Minibatch Loss= 0.0073, Training Accuracy= 0.9990, Minibatch error= 0.1%
# 2019-07-28 10:57:18,621 Iter 11, Minibatch Loss= 0.0195, Training Accuracy= 0.9955, Minibatch error= 0.5%
# 2019-07-28 10:57:33,346 Iter 12, Minibatch Loss= 0.0002, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-28 10:57:48,158 Iter 13, Minibatch Loss= 0.0020, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-28 10:58:02,991 Iter 14, Minibatch Loss= 0.0001, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-28 10:58:17,983 Iter 15, Minibatch Loss= 0.0001, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-28 10:58:33,176 Iter 16, Minibatch Loss= 0.0673, Training Accuracy= 0.9859, Minibatch error= 1.4%
# 2019-07-28 10:58:48,492 Iter 17, Minibatch Loss= 0.1966, Training Accuracy= 0.9502, Minibatch error= 5.0%
# 2019-07-28 10:59:03,515 Iter 18, Minibatch Loss= 0.0085, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-28 10:59:18,417 Iter 19, Minibatch Loss= 0.0595, Training Accuracy= 0.9784, Minibatch error= 2.2%
# 2019-07-28 10:59:33,399 Iter 20, Minibatch Loss= 0.0172, Training Accuracy= 0.9981, Minibatch error= 0.2%
# 2019-07-28 10:59:48,670 Iter 21, Minibatch Loss= 0.1774, Training Accuracy= 0.9566, Minibatch error= 4.3%
# 2019-07-28 11:00:03,607 Iter 22, Minibatch Loss= 0.0157, Training Accuracy= 0.9955, Minibatch error= 0.5%
# 2019-07-28 11:00:18,496 Iter 23, Minibatch Loss= 0.0019, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-28 11:00:33,806 Iter 24, Minibatch Loss= 0.0027, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-28 11:00:48,776 Iter 25, Minibatch Loss= 0.0000, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-28 11:01:03,751 Iter 26, Minibatch Loss= 0.0036, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-28 11:01:18,788 Iter 27, Minibatch Loss= 0.0135, Training Accuracy= 0.9973, Minibatch error= 0.3%
# 2019-07-28 11:01:33,728 Iter 28, Minibatch Loss= 0.0042, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-28 11:01:48,699 Iter 29, Minibatch Loss= 0.0270, Training Accuracy= 0.9930, Minibatch error= 0.7%
# 2019-07-28 11:02:03,775 Iter 30, Minibatch Loss= 0.0653, Training Accuracy= 0.9784, Minibatch error= 2.2%
# 2019-07-28 11:02:18,684 Iter 31, Minibatch Loss= 0.0025, Training Accuracy= 0.9998, Minibatch error= 0.0%
# 2019-07-28 11
Minibatch Loss= 0.0121, Training Accuracy= 0.9990, Minibatch error= 0.1%
# 2019-07-28 17:32:48,584 Iter 1551, Minibatch Loss= 0.0022, Training Accuracy= 0.9998, Minibatch error= 0.0%
# 2019-07-28 17:33:03,332 Iter 1552, Minibatch Loss= 0.0004, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-28 17:33:18,093 Iter 1553, Minibatch Loss= 0.0023, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-28 17:33:33,061 Iter 1554, Minibatch Loss= 0.0114, Training Accuracy= 0.9955, Minibatch error= 0.5%
# 2019-07-28 17:33:48,083 Iter 1555, Minibatch Loss= 0.0429, Training Accuracy= 0.9893, Minibatch error= 1.1%
# 2019-07-28 17:34:03,237 Iter 1556, Minibatch Loss= 0.1503, Training Accuracy= 0.9502, Minibatch error= 5.0%
# 2019-07-28 17:34:17,917 Iter 1557, Minibatch Loss= 0.0001, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-28 17:34:32,723 Iter 1558, Minibatch Loss= 0.0114, Training Accuracy= 0.9955, Minibatch error= 0.5%
# 2019-07-28 17:34:47,413 Iter 1559, Minibatch Loss= 0.0059, Training Accuracy= 0.9992, Minibatch error= 0.1%
# 2019-07-28 17:35:02,316 Iter 1560, Minibatch Loss= 0.0298, Training Accuracy= 0.9904, Minibatch error= 1.0%
# 2019-07-28 17:35:17,159 Iter 1561, Minibatch Loss= 0.0121, Training Accuracy= 0.9990, Minibatch error= 0.1%
# 2019-07-28 17:35:31,888 Iter 1562, Minibatch Loss= 0.0216, Training Accuracy= 0.9930, Minibatch error= 0.7%
# 2019-07-28 17:35:46,684 Iter 1563, Minibatch Loss= 0.0127, Training Accuracy= 0.9973, Minibatch error= 0.3%
# 2019-07-28 17:36:01,671 Iter 1564, Minibatch Loss= 0.0429, Training Accuracy= 0.9893, Minibatch error= 1.1%
# 2019-07-28 17:36:16,565 Iter 1565, Minibatch Loss= 0.0505, Training Accuracy= 0.9784, Minibatch error= 2.2%
# 2019-07-28 17:36:31,214 Iter 1566, Minibatch Loss= 0.0001, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-28 17:36:46,095 Iter 1567, Minibatch Loss= 0.0054, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-28 17:36:46,095 Epoch 48, Average loss: 0.0287, learning rate: 0.0000
# 2019-07-28 17:37:05,030 Verification error= 0.0%, loss= 0.0036
# 2019-07-28 17:37:21,234 Iter 1568, Minibatch Loss= 0.0025, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-28 17:37:36,046 Iter 1569, Minibatch Loss= 0.0001, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-28 17:37:50,809 Iter 1570, Minibatch Loss= 0.0099, Training Accuracy= 0.9981, Minibatch error= 0.2%
# 2019-07-28 17:38:05,880 Iter 1571, Minibatch Loss= 0.1554, Training Accuracy= 0.9566, Minibatch error= 4.3%
# 2019-07-28 17:38:20,684 Iter 1572, Minibatch Loss= 0.0023, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-28 17:38:35,683 Iter 1573, Minibatch Loss= 0.0009, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-28 17:38:50,537 Iter 1574, Minibatch Loss= 0.0110, Training Accuracy= 0.9986, Minibatch error= 0.1%
# 2019-07-28 17:39:05,253 Iter 1575, Minibatch Loss= 0.0022, Training Accuracy= 0.9998, Minibatch error= 0.0%
# 2019-07-28 17:39:20,280 Iter 1576, Minibatch Loss= 0.0060, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-28 17:39:35,002 Iter 1577, Minibatch Loss= 0.0084, Training Accuracy= 0.9980, Minibatch error= 0.2%
# 2019-07-28 17:39:49,807 Iter 1578, Minibatch Loss= 0.0049, Training Accuracy= 0.9983, Minibatch error= 0.2%
# 2019-07-28 17:40:04,631 Iter 1579, Minibatch Loss= 0.0057, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-28 17:40:19,688 Iter 1580, Minibatch Loss= 0.0501, Training Accuracy= 0.9859, Minibatch error= 1.4%
# 2019-07-28 17:40:34,281 Iter 1581, Minibatch Loss= 0.0004, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-28 17:40:49,166 Iter 1582, Minibatch Loss= 0.0023, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-28 17:41:03,949 Iter 1583, Minibatch Loss= 0.0054, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-28 17:41:18,728 Iter 1584, Minibatch Loss= 0.0505, Training Accuracy= 0.9784, Minibatch error= 2.2%
# 2019-07-28 17:41:33,650 Iter 1585, Minibatch Loss= 0.0298, Training Accuracy= 0.9904, Minibatch error= 1.0%
# 2019-07-28 17:41:48,496 Iter 1586, Minibatch Loss= 0.0127, Training Accuracy= 0.9973, Minibatch error= 0.3%
# 2019-07-28 17:42:03,251 Iter 1587, Minibatch Loss= 0.0001, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-28 17:42:18,059 Iter 1588, Minibatch Loss= 0.0060, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-28 17:42:32,664 Iter 1589, Minibatch Loss= 0.0001, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-28 17:42:47,502 Iter 1590, Minibatch Loss= 0.0025, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-28 17:43:02,303 Iter 1591, Minibatch Loss= 0.0049, Training Accuracy= 0.9983, Minibatch error= 0.2%
# 2019-07-28 17:43:17,151 Iter 1592, Minibatch Loss= 0.0059, Training Accuracy= 0.9992, Minibatch error= 0.1%
# 2019-07-28 17:43:31,970 Iter 1593, Minibatch Loss= 0.0121, Training Accuracy= 0.9990, Minibatch error= 0.1%
# 2019-07-28 17:43:46,936 Iter 1594, Minibatch Loss= 0.0429, Training Accuracy= 0.9893, Minibatch error= 1.1%
# 2019-07-28 17:44:01,837 Iter 1595, Minibatch Loss= 0.0009, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-28 17:44:17,127 Iter 1596, Minibatch Loss= 0.1554, Training Accuracy= 0.9566, Minibatch error= 4.3%
# 2019-07-28 17:44:31,905 Iter 1597, Minibatch Loss= 0.0110, Training Accuracy= 0.9986, Minibatch error= 0.1%
# 2019-07-28 17:44:46,740 Iter 1598, Minibatch Loss= 0.0004, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-28 17:45:01,811 Iter 1599, Minibatch Loss= 0.0501, Training Accuracy= 0.9859, Minibatch error= 1.4%
# 2019-07-28 17:45:01,811 Epoch 49, Average loss: 0.0213, learning rate: 0.0000
# 2019-07-28 17:45:20,825 Verification error= 0.0%, loss= 0.0036
# 2019-07-28 17:45:22,233 Optimization Finished!

# %%
import tensorflow as tf
epochs = 50
acc=[]
acc_=[]
loss=[]
loss_=[]
lr=[]
lr_=[]

import glob
eventfile = glob.glob(output_path+'/*.yao')[0]

for event in tf.train.summary_iterator(eventfile):
#    for value in event.summary.value:
#        print(value.tag)
#        if value.HasField('simple_value'):
#            print(value.simple_value)
    for v in event.summary.value:
        if v.tag == 'accuracy':
            acc.append(v.simple_value)
        if v.tag == 'loss':
            loss.append(v.simple_value)
        if v.tag == 'learning_rate':
            lr.append(v.simple_value)

iter = np.arange(0, len(acc))
iter_=[]
epoch = np.arange(0, epochs)

for i in np.arange(0,len(acc),int(len(acc)/epochs)):
    acc_.append(np.mean(acc[i:i+int(len(acc)/epochs)]))
    loss_.append(np.mean(loss[i:i+int(len(loss)/epochs)]))
    lr_.append(np.mean(lr[i:i+int(len(lr)/epochs)]))
    iter_.append(np.mean(iter[i:i+int(len(iter)/epochs)]))

plt.figure()
plt.plot(iter, acc, lw=1, linestyle = '--')
plt.plot(iter_, acc_)
plt.xlabel('iterations')
plt.ylabel('accuracy')
plt.ylim([0.9,1])
plt.figure()
plt.plot(iter, loss, lw=1, linestyle = '--')
plt.plot(iter_, loss_)
plt.xlabel('iterations')
plt.ylabel('loss')
plt.ylim([0,0.2])
print('loss in the final epoch is '+ str(loss_[len(epoch)-1]))
plt.figure()
plt.plot(iter, lr, lw=1, linestyle = '--')
plt.plot(iter_, lr_)
plt.xlabel('iterations')
plt.ylabel('learning rate')
plt.ylim([0,1])
# Out:
# WARNING:tensorflow:From /home/yao/anaconda3/lib/python3.6/site-packages/tensorflow/python/summary/summary_iterator.py:68: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# 2019-07-28 21:05:38,096 From /home/yao/anaconda3/lib/python3.6/site-packages/tensorflow/python/summary/summary_iterator.py:68: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# loss in the final epoch is 0.020394732342765565
# (0, 1)

# %% [markdown]
# ### Test performance

# %%
#prepare test data
test_data = image_util.ImageDataProvider("./data_testset_20190717/*.tif")
i=6 #number of images
x_test, y_test = test_data(i)

net = unet.Unet(layers=3, features_root=32, channels=1, n_class=2)
prediction = net.predict(output_path+"/model.ckpt", x_test)

print(x_test.shape)
print(y_test.shape)
print(prediction.shape)
# Out:
# 2019-08-07 19:29:15,575 Layers 3, features 32, filter size 3x3, pool size: 2x2
# Number of files used: 6
# Number of channels: 1
# Number of classes: 2
# WARNING:tensorflow:From /home/yao/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# 2019-08-07 19:29:15,634 From /home/yao/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/yao/.local/lib/python3.6/site-packages/tf_unet-0.1.2-py3.6.egg/tf_unet/layers.py:39: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# 2019-08-07 19:29:15,655 From /home/yao/.local/lib/python3.6/site-packages/tf_unet-0.1.2-py3.6.egg/tf_unet/layers.py:39: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /home/yao/anaconda3/lib/python3.6/site-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# 2019-08-07 19:29:16,376 From /home/yao/anaconda3/lib/python3.6/site-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50_LR1.4_D0.8_M0.5_data_trainset_20190717/model.ckpt
# 2019-08-07 19:29:16,379 Restoring parameters from ./trained_3layers_feature32_epoch50_LR1.4_D0.8_M0.5_data_trainset_20190717/model.ckpt
# 2019-08-07 19:29:16,471 Model restored from file: ./trained_3layers_feature32_epoch50_LR1.4_D0.8_M0.5_data_trainset_20190717/model.ckpt
# (6, 1000, 1000, 1)
# (6, 1000, 1000, 2)
# (6, 960, 960, 2)

# %%
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, precision_score, recall_score, log_loss, f1_score, classification_report
from sklearn.metrics import roc_curve, auc, roc_auc_score, precision_recall_curve, average_precision_score, accuracy_score

#test_y = y_test[...,20:1020,20:1020,1].flatten()
test_y = y_test[...,20:980,20:980,1].flatten()
test_y_predict = prediction[...,1].flatten()
predict_max = max(test_y_predict)
test_y_predict = test_y_predict/predict_max

print(max(test_y))
print(max(test_y_predict))
print(test_y.shape)
print(test_y_predict.shape)

print(classification_report(test_y, (test_y_predict > 0.3)))
# Out:
# 1.0
# 1.0
# (5529600,)
# (5529600,)
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.96      0.98   5499496
#          1.0       0.08      0.69      0.15     30104
#
#    micro avg       0.96      0.96      0.96   5529600
#    macro avg       0.54      0.82      0.56   5529600
# weighted avg       0.99      0.96      0.97   5529600

# %%
print(classification_report(test_y, (test_y_predict > 0.29)))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.96      0.98   5499496
#          1.0       0.08      0.70      0.15     30104
#
#    micro avg       0.96      0.96      0.96   5529600
#    macro avg       0.54      0.83      0.56   5529600
# weighted avg       0.99      0.96      0.97   5529600

# %%
fpr, tpr, thresholds = roc_curve(test_y, test_y_predict)
roc_auc = auc(fpr, tpr)

plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange', lw=lw, label = 'ROC curve (area = %0.4f)' % roc_auc)
plt.plot([0, 1], [0, 1], color = 'navy', lw=lw, linestyle = '--')
plt.xlim([0,1])
plt.ylim([0,1])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc = 'lower right')
plt.show()
print('AUC = ',roc_auc)

precision, recall, thresholds = precision_recall_curve(test_y, test_y_predict)
AP = average_precision_score(test_y, test_y_predict)
plt.figure()
plt.plot(recall, precision, label = 'Average Precision (area = %0.4f)' % AP)
plt.plot([0, 1], [1, 0], color = 'navy', lw=lw, linestyle = '--')
plt.xlim([0,1])
plt.ylim([0,1])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.legend(loc = 'lower right')
plt.show()
print('AP = ',AP)
# Out:
# AUC =  0.9646147363446691
# AP =  0.25495347215472475

# %%
import scipy.io as sio
dict={
    "iter_":iter_,
    "acc_":acc_,
    "loss_":loss_,
    "lr_":lr_,
    "fprate":fpr, 
    "tprate":tpr,
    "recall":recall, 
    "precision":precision
}

sio.savemat('performance'+prediction_path[12:]+'.mat', dict)

# %% [markdown]
# ### prediction on frac and nonfrac on Ross ice shelf

# %%
#prepare test data
test_data = image_util.ImageDataProvider("./data_ross/*.tif")
i=2 #number of images
x_test, y_test = test_data(i)
print(x_test.shape)
print(y_test.shape)

prediction = net.predict(output_path+"/model.ckpt", x_test)
# Out:
# Number of files used: 2
# Number of channels: 1
# Number of classes: 2
# (2, 1000, 1000, 1)
# (2, 1000, 1000, 2)
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50_LR0.4_D0.95_M0.2/model.ckpt
# 2019-06-13 21:45:26,250 Restoring parameters from ./trained_3layers_feature32_epoch50_LR0.4_D0.95_M0.2/model.ckpt
# 2019-06-13 21:45:26,327 Model restored from file: ./trained_3layers_feature32_epoch50_LR0.4_D0.95_M0.2/model.ckpt

# %%
# display
i=1#sample index
fig, ax = plt.subplots(1, 3, sharex=True, sharey=True, figsize=(15,5))
ax[0].imshow(x_test[i,...,0], aspect="auto")
ax[1].imshow(y_test[i,...,1], aspect="auto")
mask = prediction[i,...,1] > 0.3
ax[2].imshow(mask, aspect="auto")
ax[0].set_title("Input")
ax[1].set_title("Ground truth")
ax[2].set_title("Prediction")
fig.tight_layout()

# %%
# save as image
img = util.combine_img_prediction(x_test, y_test, prediction)
util.save_image(img, prediction_path+"/prediction_ross.jpg")

# %% [markdown]
# ### prediction on sample images

# %%
#prepare test data
test_data = image_util.ImageDataProvider("./data_sample/*.tif")
i=4 #number of images
x_test, y_test = test_data(i)
print(x_test.shape)
print(y_test.shape)

prediction = net.predict(output_path+"/model.ckpt", x_test)
# Out:
# Number of files used: 4
# Number of channels: 1
# Number of classes: 2
# (4, 241, 241, 1)
# (4, 241, 241, 2)
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-08 04:26:35,559 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-08 04:26:35,788 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt

# %%
# display
i=2 #sample index
fig, ax = plt.subplots(1, 3, sharex=True, sharey=True, figsize=(12,5))
ax[0].imshow(x_test[i,...,0], aspect="auto")
ax[1].imshow(y_test[i,...,1], aspect="auto")
mask = prediction[i,...,1] > 0.1
ax[2].imshow(mask, aspect="auto")
ax[0].set_title("Input")
ax[1].set_title("Ground truth")
ax[2].set_title("Prediction")
fig.tight_layout()

# %%
img = util.combine_img_prediction(x_test, y_test, prediction)
util.save_image(img, prediction_path+"/prediction_sample.jpg")

# %% [markdown]
# ### Apply to Antarctica

# %%
#prepare test data
for i in range (1,37):
    for j in range (1,44):
        test_data = image_util.ImageDataProvider("./data_Antarctica/MOA209_125m_mask"+str(i)+"x"+str(j)+".tif")
        x_test, y_test = test_data(1) # 1 image
        x_test_ = x_test[0,...,0]
        if x_test_.sum()!=0:
            prediction = net.predict(output_path+"/model.ckpt", x_test)
       #    print(prediction.shape)
            prediction = prediction[0,...,1]
            prediction = prediction/predict_max #rescale with max of test data
            #scipy.io.savemat('./predict_Antarctica_epoch50/prediction.mat', mdict={"prediction"+str(i)+"x"+str(j): prediction})
            matplotlib.image.imsave("./predict_Antarctica"+prediction_path[12:]+"/prediction"+str(i)+"x"+str(j)+".tif", prediction, vmin = 0, vmax = 1)
# Out:
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:36:35,542 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:36:35,590 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:36:38,709 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:36:38,789 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:36:42,222 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:36:42,306 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:36:45,608 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:36:45,661 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:36:48,661 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:36:48,714 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:36:51,728 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:36:51,780 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:36:54,745 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:36:54,798 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:36:57,784 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:36:57,839 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:00,880 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:00,935 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:03,942 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:04,004 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:07,921 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:08,000 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:11,208 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:11,295 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:14,543 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:14,627 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:17,837 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:17,925 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:20,968 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:21,052 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:24,575 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:24,676 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:28,626 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:28,746 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:32,297 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:32,420 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:37,230 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:37,329 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:40,686 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:40,781 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:44,496 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:44,605 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:48,009 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:48,114 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:52,561 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:52,670 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:55,966 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:56,077 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:59,320 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:59,416 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:03,024 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:03,106 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:06,053 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:06,161 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:09,500 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:09,617 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:12,806 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:12,913 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:17,057 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:17,148 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:20,142 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:20,264 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:23,473 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:23,589 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:26,576 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:26,689 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:30,307 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:30,419 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:33,495 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:33,618 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:36,596 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:36,724 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:39,743 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:39,865 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:42,981 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:43,113 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:46,184 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:46,316 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:49,253 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:49,388 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:52,432 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:52,555 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:55,535 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:55,680 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:58,653 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:58,784 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:02,102 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:02,211 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:05,578 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:05,694 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:08,927 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:09,091 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:12,274 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:12,418 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:16,012 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:16,177 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:19,388 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:19,522 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:22,599 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:22,745 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:25,876 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:26,025 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:29,110 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:29,251 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:32,464 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:32,659 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:36,169 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:36,351 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:39,802 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:39,954 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:43,021 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:43,168 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:46,311 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:46,461 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:49,645 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:49,804 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:53,194 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:53,346 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:56,461 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:56,613 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-64c11fa4b4c4> in <module>
#       6         x_test_ = x_test[0,...,0]
#       7         if x_test_.sum()!=0:
# ----> 8             prediction = net.predict(output_path+"/model.ckpt", x_test)
#       9        #    print(prediction.shape)
#      10             prediction = prediction[0,...,1]
#
# ~/.local/lib/python3.6/site-packages/tf_unet-0.1.2-py3.6.egg/tf_unet/unet.py in predict(self, model_path, x_test)
#     275
#     276             y_dummy = np.empty((x_test.shape[0], x_test.shape[1], x_test.shape[2], self.n_class))
# --> 277             prediction = sess.run(self.predicter, feed_dict={self.x: x_test, self.y: y_dummy, self.keep_prob: 1.})
#     278
#     279         return prediction
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1332   def _do_call(self, fn, *args):
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#    1336       message = compat.as_text(e.message)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#    1321     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1405     return tf_session.TF_SessionRun_wrapper(
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#    1409   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
