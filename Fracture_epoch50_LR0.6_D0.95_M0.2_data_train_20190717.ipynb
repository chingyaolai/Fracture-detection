# %%
from __future__ import division, print_function
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
plt.rcParams['image.cmap'] = 'gray'
np.random.seed(98765)

# %%
from tf_unet import image_util
from tf_unet import unet
from tf_unet import util

# %%
prediction_path = "./prediction_3layers_feature32_epoch50_LR0.6_D0.95_M0.2_data_train_20190717"
output_path = "./trained_3layers_feature32_epoch50_LR0.6_D0.95_M0.2_data_train_20190717"
training_data = image_util.ImageDataProvider("./data_train_20190717/*.tif")
# Out:
# Number of files used: 32
# Number of channels: 1
# Number of classes: 2

# %%
i=32 #number of images
x_train, y_train = training_data(i)
print(x_train.shape)

#train_y = y_train[...,1].flatten()
#print(train_y.max())
#train_x = x_train[...,0].flatten()
#print(train_x.max())
# Out:
# (32, 1000, 1000, 1)

# %%
net = unet.Unet(layers=3, features_root=32, channels=1, n_class=2)
trainer = unet.Trainer(net, optimizer="momentum", opt_kwargs=dict(momentum=0.2,learning_rate=0.6,decay_rate=0.95))
#trainer = unet.Trainer(net)
path = trainer.train(training_data, output_path, training_iters=32, epochs=50, 
                     display_step=1, prediction_path=prediction_path)
# Out:
# 2019-07-17 20:43:51,641 Layers 3, features 32, filter size 3x3, pool size: 2x2
# WARNING:tensorflow:From /home/yao/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# 2019-07-17 20:43:51,739 From /home/yao/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/yao/.local/lib/python3.6/site-packages/tf_unet-0.1.2-py3.6.egg/tf_unet/layers.py:39: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# 2019-07-17 20:43:51,794 From /home/yao/.local/lib/python3.6/site-packages/tf_unet-0.1.2-py3.6.egg/tf_unet/layers.py:39: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# 2019-07-17 20:43:53,308 Removing '/home/yao/Downloads/tf_unet-master/demo/prediction_3layers_feature32_epoch50_LR0.6_D0.95_M0.2_data_train_20190717'
# 2019-07-17 20:43:53,308 Removing '/home/yao/Downloads/tf_unet-master/demo/trained_3layers_feature32_epoch50_LR0.6_D0.95_M0.2_data_train_20190717'
# 2019-07-17 20:43:53,309 Allocating '/home/yao/Downloads/tf_unet-master/demo/prediction_3layers_feature32_epoch50_LR0.6_D0.95_M0.2_data_train_20190717'
# 2019-07-17 20:43:53,309 Allocating '/home/yao/Downloads/tf_unet-master/demo/trained_3layers_feature32_epoch50_LR0.6_D0.95_M0.2_data_train_20190717'
# 2019-07-17 20:44:15,377 Verification error= 72.7%, loss= 0.6972
# 2019-07-17 20:44:16,289 Start optimization
# 2019-07-17 20:44:32,998 Iter 0, Minibatch Loss= 0.5088, Training Accuracy= 0.9743, Minibatch error= 2.6%
# 2019-07-17 20:44:48,107 Iter 1, Minibatch Loss= 0.1695, Training Accuracy= 0.9930, Minibatch error= 0.7%
# 2019-07-17 20:45:03,143 Iter 2, Minibatch Loss= 0.0032, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 20:45:18,262 Iter 3, Minibatch Loss= 0.0004, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 20:45:33,621 Iter 4, Minibatch Loss= 0.0061, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-17 20:45:48,372 Iter 5, Minibatch Loss= 0.0078, Training Accuracy= 0.9992, Minibatch error= 0.1%
# 2019-07-17 20:46:03,360 Iter 6, Minibatch Loss= 0.0062, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-17 20:46:18,859 Iter 7, Minibatch Loss= 0.0002, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 20:46:34,410 Iter 8, Minibatch Loss= 0.0117, Training Accuracy= 0.9990, Minibatch error= 0.1%
# 2019-07-17 20:46:49,225 Iter 9, Minibatch Loss= 0.0148, Training Accuracy= 0.9986, Minibatch error= 0.1%
# 2019-07-17 20:47:04,403 Iter 10, Minibatch Loss= 0.0184, Training Accuracy= 0.9980, Minibatch error= 0.2%
# 2019-07-17 20:47:19,266 Iter 11, Minibatch Loss= 0.0471, Training Accuracy= 0.9935, Minibatch error= 0.6%
# 2019-07-17 20:47:34,394 Iter 12, Minibatch Loss= 0.0023, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 20:47:49,310 Iter 13, Minibatch Loss= 0.0014, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 20:48:04,317 Iter 14, Minibatch Loss= 0.0204, Training Accuracy= 0.9973, Minibatch error= 0.3%
# 2019-07-17 20:48:19,688 Iter 15, Minibatch Loss= 0.0744, Training Accuracy= 0.9859, Minibatch error= 1.4%
# 2019-07-17 20:48:36,189 Iter 16, Minibatch Loss= 0.0059, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 20:48:52,177 Iter 17, Minibatch Loss= 0.1957, Training Accuracy= 0.9566, Minibatch error= 4.3%
# 2019-07-17 20:49:07,729 Iter 18, Minibatch Loss= 0.0239, Training Accuracy= 0.9981, Minibatch error= 0.2%
# 2019-07-17 20:49:22,433 Iter 19, Minibatch Loss= 0.0042, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 20:49:37,057 Iter 20, Minibatch Loss= 0.0792, Training Accuracy= 0.9784, Minibatch error= 2.2%
# 2019-07-17 20:49:51,758 Iter 21, Minibatch Loss= 0.0055, Training Accuracy= 0.9998, Minibatch error= 0.0%
# 2019-07-17 20:50:06,403 Iter 22, Minibatch Loss= 0.0429, Training Accuracy= 0.9904, Minibatch error= 1.0%
# 2019-07-17 20:50:21,161 Iter 23, Minibatch Loss= 0.0050, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 20:50:35,757 Iter 24, Minibatch Loss= 0.0038, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-17 20:50:50,428 Iter 25, Minibatch Loss= 0.0093, Training Accuracy= 0.9983, Minibatch error= 0.2%
# 2019-07-17 20:51:05,418 Iter 26, Minibatch Loss= 0.2097, Training Accuracy= 0.9502, Minibatch error= 5.0%
# 2019-07-17 20:51:20,066 Iter 27, Minibatch Loss= 0.0097, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 20:51:34,835 Iter 28, Minibatch Loss= 0.0102, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 20:51:49,578 Iter 29, Minibatch Loss= 0.0138, Training Accuracy= 0.9986, Minibatch error= 0.1%
# 2019-07-17 20:52:04,459 Iter 30, Minibatch Loss= 0.0073, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 20:52:19,255 Iter 31, Minibatch Loss= 0.0027, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-17 20:52:19,255 Epoch 0, Average loss: 0.0787, learning rate: 0.6000
# 2019-07-17 20:52:38,005 Verification error= 0.4%, loss= 0.0186
# 2019-07-17 20:52:53,539 Iter 32, Minibatch Loss= 0.0005, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 20:53:08,322 Iter 33, Minibatch Loss= 0.0040, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-17 20:53:22,917 Iter 34, Minibatch Loss= 0.0034, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-17 20:53:37,684 Iter 35, Minibatch Loss= 0.0026, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 20:53:52,500 Iter 36, Minibatch Loss= 0.0665, Training Accuracy= 0.9859, Minibatch error= 1.4%
# 2019-07-17 20:54:07,190 Iter 37, Minibatch Loss= 0.0027, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 20:54:22,136 Iter 38, Minibatch Loss= 0.0914, Training Accuracy= 0.9743, Minibatch error= 2.6%
# 2019-07-17 20:54:36,744 Iter 39, Minibatch Loss= 0.0007, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 20:54:52,182 Iter 40, Minibatch Loss= 0.1724, Training Accuracy= 0.9566, Minibatch error= 4.3%
# 2019-07-17 20:55:08,091 Iter 41, Minibatch Loss= 0.0421, Training Accuracy= 0.9904, Minibatch error= 1.0%
# 2019-07-17 20:55:22,878 Iter 42, Minibatch Loss= 0.0115, Training Accuracy= 0.9981, Minibatch error= 0.2%
# 2019-07-17 20:55:37,267 Iter 43, Minibatch Loss= 0.0005, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 20:55:51,786 Iter 44, Minibatch Loss= 0.0002, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 20:56:06,437 Iter 45, Minibatch Loss= 0.0230, Training Accuracy= 0.9935, Minibatch error= 0.6%
# 2019-07-17 20:56:21,314 Iter 46, Minibatch Loss= 0.0003, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 20:56:35,994 Iter 47, Minibatch Loss= 0.0095, Training Accuracy= 0.9980, Minibatch error= 0.2%
# 2019-07-17 20:56:50,622 Iter 48, Minibatch Loss= 0.0511, Training Accuracy= 0.9893, Minibatch error= 1.1%
# 2019-07-17 20:57:05,374 Iter 49, Minibatch Loss= 0.0588, Training Accuracy= 0.9784, Minibatch error= 2.2%
# 2019-07-17 20:57:20,064 Iter 50, Minibatch Loss= 0.0169, Training Accuracy= 0.9990, Minibatch error= 0.1%
# 2019-07-17 20:57:34,563 Iter 51, Minibatch Loss= 0.0060, Training Accuracy= 0.9983, Minibatch error= 0.2%
# 2019-07-17 20:57:49,328 Iter 52, Minibatch Loss= 0.0277, Training Accuracy= 0.9930, Minibatch error= 0.7%
# 2019-07-17 20:58:03,889 Iter 53, Minibatch Loss= 0.0029, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 20:58:18,600 Iter 54, Minibatch Loss= 0.0130, Training Accuracy= 0.9973, Minibatch error= 0.3%
# 2019-07-17 20:58:33,690 Iter 55, Minibatch Loss= 0.1751, Training Accuracy= 0.9502, Minibatch error= 5.0%
# 2019-07-17 20:58:48,253 Iter 56, Minibatch Loss= 0.0119, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 20:59:02,889 Iter 57, Minibatch Loss= 0.0145, Training Accuracy= 0.9955, Minibatch error= 0.5%
# 2019-07-17 20:59:17,466 Iter 58, Minibatch Loss= 0.0073, Training Accuracy= 0.9992, Minibatch error= 0.1%
# 2019-07-17 20:59:32,108 Iter 59, Minibatch Loss= 0.0033, Training Accuracy= 0.9998, Minibatch error= 0.0%
# 2019-07-17 20:59:46,741 Iter 60, Minibatch Loss= 0.0139, Training Accuracy= 0.9973, Minibatch error= 0.3%
# 2019-07-17 21:00:01,265 Iter 61, Minibatch Loss= 0.0067, Training Accuracy= 0.9992, Minibatch error= 0.1%
# 2019-07-17 21:00:16,035 Iter 62, Minibatch Loss= 0.0068, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:00:31,066 Iter 63, Minibatch Loss= 0.1829, Training Accuracy= 0.9502, Minibatch error= 5.0%
# 2019-07-17 21:00:31,067 Epoch 1, Average loss: 0.0347, learning rate: 0.5700
# 2019-07-17 21:00:49,748 Verification error= 0.4%, loss= 0.0220
# 2019-07-17 21:01:05,215 Iter 64, Minibatch Loss= 0.0054, Training Accuracy= 0.9983, Minibatch error= 0.2%
# 2019-07-17 21:01:19,794 Iter 65, Minibatch Loss= 0.0117, Training Accuracy= 0.9980, Minibatch error= 0.2%
# 2019-07-17 21:01:34,408 Iter 66, Minibatch Loss= 0.0004, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:01:49,154 Iter 67, Minibatch Loss= 0.0894, Training Accuracy= 0.9743, Minibatch error= 2.6%
# 2019-07-17 21:02:03,858 Iter 68, Minibatch Loss= 0.0090, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-17 21:02:18,608 Iter 69, Minibatch Loss= 0.0146, Training Accuracy= 0.9955, Minibatch error= 0.5%
# 2019-07-17 21:02:33,437 Iter 70, Minibatch Loss= 0.0597, Training Accuracy= 0.9859, Minibatch error= 1.4%
# 2019-07-17 21:02:48,131 Iter 71, Minibatch Loss= 0.0047, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:03:02,671 Iter 72, Minibatch Loss= 0.0007, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:03:17,509 Iter 73, Minibatch Loss= 0.0096, Training Accuracy= 0.9981, Minibatch error= 0.2%
# 2019-07-17 21:03:32,240 Iter 74, Minibatch Loss= 0.0001, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:03:46,778 Iter 75, Minibatch Loss= 0.0001, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:04:01,287 Iter 76, Minibatch Loss= 0.0013, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:04:16,207 Iter 77, Minibatch Loss= 0.0008, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:04:30,871 Iter 78, Minibatch Loss= 0.0378, Training Accuracy= 0.9904, Minibatch error= 1.0%
# 2019-07-17 21:04:45,718 Iter 79, Minibatch Loss= 0.0104, Training Accuracy= 0.9990, Minibatch error= 0.1%
# 2019-07-17 21:05:00,446 Iter 80, Minibatch Loss= 0.0497, Training Accuracy= 0.9893, Minibatch error= 1.1%
# 2019-07-17 21:05:15,368 Iter 81, Minibatch Loss= 0.1957, Training Accuracy= 0.9566, Minibatch error= 4.3%
# 2019-07-17 21:05:29,990 Iter 82, Minibatch Loss= 0.0009, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:05:44,556 Iter 83, Minibatch Loss= 0.0047, Training Accuracy= 0.9998, Minibatch error= 0.0%
# 2019-07-17 21:05:59,204 Iter 84, Minibatch Loss= 0.0097, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:06:13,848 Iter 85, Minibatch Loss= 0.0004, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:06:28,556 Iter 86, Minibatch Loss= 0.0043, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-17 21:06:43,210 Iter 87, Minibatch Loss= 0.0158, Training Accuracy= 0.9986, Minibatch error= 0.1%
# 2019-07-17 21:06:57,833 Iter 88, Minibatch Loss= 0.0215, Training Accuracy= 0.9935, Minibatch error= 0.6%
# 2019-07-17 21:07:12,573 Iter 89, Minibatch Loss= 0.0270, Training Accuracy= 0.9930, Minibatch error= 0.7%
# 2019-07-17 21:07:27,479 Iter 90, Minibatch Loss= 0.0062, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-17 21:07:42,165 Iter 91, Minibatch Loss= 0.0566, Training Accuracy= 0.9784, Minibatch error= 2.2%
# 2019-07-17 21:07:56,992 Iter 92, Minibatch Loss= 0.0177, Training Accuracy= 0.9986, Minibatch error= 0.1%
# 2019-07-17 21:08:11,923 Iter 93, Minibatch Loss= 0.0889, Training Accuracy= 0.9743, Minibatch error= 2.6%
# 2019-07-17 21:08:26,751 Iter 94, Minibatch Loss= 0.0536, Training Accuracy= 0.9784, Minibatch error= 2.2%
# 2019-07-17 21:08:41,468 Iter 95, Minibatch Loss= 0.0004, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:08:41,469 Epoch 2, Average loss: 0.0274, learning rate: 0.5415
# 2019-07-17 21:09:00,151 Verification error= 0.4%, loss= 0.0217
# 2019-07-17 21:09:15,968 Iter 96, Minibatch Loss= 0.0607, Training Accuracy= 0.9859, Minibatch error= 1.4%
# 2019-07-17 21:09:30,649 Iter 97, Minibatch Loss= 0.0046, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-17 21:09:45,667 Iter 98, Minibatch Loss= 0.1944, Training Accuracy= 0.9502, Minibatch error= 5.0%
# 2019-07-17 21:10:00,325 Iter 99, Minibatch Loss= 0.0168, Training Accuracy= 0.9955, Minibatch error= 0.5%
# 2019-07-17 21:10:14,832 Iter 100, Minibatch Loss= 0.0172, Training Accuracy= 0.9973, Minibatch error= 0.3%
# 2019-07-17 21:10:29,515 Iter 101, Minibatch Loss= 0.0061, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-17 21:10:44,215 Iter 102, Minibatch Loss= 0.0237, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:10:58,960 Iter 103, Minibatch Loss= 0.0155, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:11:13,605 Iter 104, Minibatch Loss= 0.0096, Training Accuracy= 0.9980, Minibatch error= 0.2%
# 2019-07-17 21:11:28,148 Iter 105, Minibatch Loss= 0.0001, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:11:42,798 Iter 106, Minibatch Loss= 0.0226, Training Accuracy= 0.9935, Minibatch error= 0.6%
# 2019-07-17 21:11:57,333 Iter 107, Minibatch Loss= 0.0053, Training Accuracy= 0.9992, Minibatch error= 0.1%
# 2019-07-17 21:12:12,018 Iter 108, Minibatch Loss= 0.0017, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:12:26,814 Iter 109, Minibatch Loss= 0.0400, Training Accuracy= 0.9904, Minibatch error= 1.0%
# 2019-07-17 21:12:41,392 Iter 110, Minibatch Loss= 0.0103, Training Accuracy= 0.9981, Minibatch error= 0.2%
# 2019-07-17 21:12:55,957 Iter 111, Minibatch Loss= 0.0036, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:13:10,528 Iter 112, Minibatch Loss= 0.0002, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:13:25,133 Iter 113, Minibatch Loss= 0.0032, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:13:39,862 Iter 114, Minibatch Loss= 0.0015, Training Accuracy= 0.9998, Minibatch error= 0.0%
# 2019-07-17 21:13:54,548 Iter 115, Minibatch Loss= 0.0271, Training Accuracy= 0.9930, Minibatch error= 0.7%
# 2019-07-17 21:14:09,080 Iter 116, Minibatch Loss= 0.0000, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:14:23,920 Iter 117, Minibatch Loss= 0.0022, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:14:38,510 Iter 118, Minibatch Loss= 0.0041, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-17 21:14:53,406 Iter 119, Minibatch Loss= 0.1726, Training Accuracy= 0.9566, Minibatch error= 4.3%
# 2019-07-17 21:15:08,089 Iter 120, Minibatch Loss= 0.0026, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:15:22,869 Iter 121, Minibatch Loss= 0.0139, Training Accuracy= 0.9990, Minibatch error= 0.1%
# 2019-07-17 21:15:37,507 Iter 122, Minibatch Loss= 0.0057, Training Accuracy= 0.9983, Minibatch error= 0.2%
# 2019-07-17 21:15:52,289 Iter 123, Minibatch Loss= 0.0519, Training Accuracy= 0.9893, Minibatch error= 1.1%
# 2019-07-17 21:16:06,966 Iter 124, Minibatch Loss= 0.0216, Training Accuracy= 0.9935, Minibatch error= 0.6%
# 2019-07-17 21:16:21,684 Iter 125, Minibatch Loss= 0.0058, Training Accuracy= 0.9983, Minibatch error= 0.2%
# 2019-07-17 21:16:36,171 Iter 126, Minibatch Loss= 0.0017, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:16:50,746 Iter 127, Minibatch Loss= 0.0001, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:16:50,747 Epoch 3, Average loss: 0.0260, learning rate: 0.5144
# 2019-07-17 21:17:09,471 Verification error= 0.4%, loss= 0.0173
# 2019-07-17 21:17:25,080 Iter 128, Minibatch Loss= 0.0001, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:17:39,720 Iter 129, Minibatch Loss= 0.0022, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:17:54,415 Iter 130, Minibatch Loss= 0.0895, Training Accuracy= 0.9743, Minibatch error= 2.6%
# 2019-07-17 21:18:09,068 Iter 131, Minibatch Loss= 0.0070, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-17 21:18:23,836 Iter 132, Minibatch Loss= 0.0096, Training Accuracy= 0.9980, Minibatch error= 0.2%
# 2019-07-17 21:18:38,527 Iter 133, Minibatch Loss= 0.0571, Training Accuracy= 0.9784, Minibatch error= 2.2%
# 2019-07-17 21:18:53,064 Iter 134, Minibatch Loss= 0.0065, Training Accuracy= 0.9992, Minibatch error= 0.1%
# 2019-07-17 21:19:07,837 Iter 135, Minibatch Loss= 0.0166, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:19:22,370 Iter 136, Minibatch Loss= 0.0113, Training Accuracy= 0.9990, Minibatch error= 0.1%
# 2019-07-17 21:19:36,996 Iter 137, Minibatch Loss= 0.0046, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:19:51,458 Iter 138, Minibatch Loss= 0.0017, Training Accuracy= 0.9998, Minibatch error= 0.0%
# 2019-07-17 21:20:06,264 Iter 139, Minibatch Loss= 0.0392, Training Accuracy= 0.9904, Minibatch error= 1.0%
# 2019-07-17 21:20:21,048 Iter 140, Minibatch Loss= 0.0038, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:20:35,968 Iter 141, Minibatch Loss= 0.1705, Training Accuracy= 0.9566, Minibatch error= 4.3%
# 2019-07-17 21:20:50,638 Iter 142, Minibatch Loss= 0.0272, Training Accuracy= 0.9930, Minibatch error= 0.7%
# 2019-07-17 21:21:05,343 Iter 143, Minibatch Loss= 0.0132, Training Accuracy= 0.9973, Minibatch error= 0.3%
# 2019-07-17 21:21:20,315 Iter 144, Minibatch Loss= 0.1683, Training Accuracy= 0.9502, Minibatch error= 5.0%
# 2019-07-17 21:21:34,881 Iter 145, Minibatch Loss= 0.0140, Training Accuracy= 0.9955, Minibatch error= 0.5%
# 2019-07-17 21:21:49,598 Iter 146, Minibatch Loss= 0.0149, Training Accuracy= 0.9986, Minibatch error= 0.1%
# 2019-07-17 21:22:04,447 Iter 147, Minibatch Loss= 0.0090, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:22:19,266 Iter 148, Minibatch Loss= 0.0095, Training Accuracy= 0.9981, Minibatch error= 0.2%
# 2019-07-17 21:22:33,964 Iter 149, Minibatch Loss= 0.0024, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-17 21:22:48,708 Iter 150, Minibatch Loss= 0.0497, Training Accuracy= 0.9893, Minibatch error= 1.1%
# 2019-07-17 21:23:03,472 Iter 151, Minibatch Loss= 0.0021, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:23:18,708 Iter 152, Minibatch Loss= 0.0596, Training Accuracy= 0.9859, Minibatch error= 1.4%
# 2019-07-17 21:23:33,437 Iter 153, Minibatch Loss= 0.0001, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:23:48,123 Iter 154, Minibatch Loss= 0.0053, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-17 21:24:02,711 Iter 155, Minibatch Loss= 0.0002, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:24:17,720 Iter 156, Minibatch Loss= 0.0365, Training Accuracy= 0.9904, Minibatch error= 1.0%
# 2019-07-17 21:24:32,418 Iter 157, Minibatch Loss= 0.0062, Training Accuracy= 0.9983, Minibatch error= 0.2%
# 2019-07-17 21:24:47,096 Iter 158, Minibatch Loss= 0.0026, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-17 21:25:01,611 Iter 159, Minibatch Loss= 0.0098, Training Accuracy= 0.9990, Minibatch error= 0.1%
# 2019-07-17 21:25:01,611 Epoch 4, Average loss: 0.0285, learning rate: 0.4887
# 2019-07-17 21:25:20,271 Verification error= 0.4%, loss= 0.0164
# 2019-07-17 21:25:35,931 Iter 160, Minibatch Loss= 0.0037, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:25:50,843 Iter 161, Minibatch Loss= 0.0490, Training Accuracy= 0.9893, Minibatch error= 1.1%
# 2019-07-17 21:26:05,446 Iter 162, Minibatch Loss= 0.0146, Training Accuracy= 0.9955, Minibatch error= 0.5%
# 2019-07-17 21:26:20,173 Iter 163, Minibatch Loss= 0.0059, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-17 21:26:34,791 Iter 164, Minibatch Loss= 0.0040, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-17 21:26:49,565 Iter 165, Minibatch Loss= 0.0584, Training Accuracy= 0.9784, Minibatch error= 2.2%
# 2019-07-17 21:27:04,229 Iter 166, Minibatch Loss= 0.0002, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:27:18,921 Iter 167, Minibatch Loss= 0.0135, Training Accuracy= 0.9973, Minibatch error= 0.3%
# 2019-07-17 21:27:33,505 Iter 168, Minibatch Loss= 0.0027, Training Accuracy= 0.9998, Minibatch error= 0.0%
# 2019-07-17 21:27:48,084 Iter 169, Minibatch Loss= 0.0001, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:28:03,439 Iter 170, Minibatch Loss= 0.0595, Training Accuracy= 0.9859, Minibatch error= 1.4%
# 2019-07-17 21:28:18,819 Iter 171, Minibatch Loss= 0.0054, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:28:33,655 Iter 172, Minibatch Loss= 0.0256, Training Accuracy= 0.9930, Minibatch error= 0.7%
# 2019-07-17 21:28:48,248 Iter 173, Minibatch Loss= 0.0213, Training Accuracy= 0.9935, Minibatch error= 0.6%
# 2019-07-17 21:29:03,073 Iter 174, Minibatch Loss= 0.0868, Training Accuracy= 0.9743, Minibatch error= 2.6%
# 2019-07-17 21:29:17,712 Iter 175, Minibatch Loss= 0.0097, Training Accuracy= 0.9980, Minibatch error= 0.2%
# 2019-07-17 21:29:32,278 Iter 176, Minibatch Loss= 0.0081, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:29:46,802 Iter 177, Minibatch Loss= 0.0005, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:30:01,379 Iter 178, Minibatch Loss= 0.0029, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:30:16,026 Iter 179, Minibatch Loss= 0.0001, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:30:30,777 Iter 180, Minibatch Loss= 0.0108, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:30:45,418 Iter 181, Minibatch Loss= 0.0098, Training Accuracy= 0.9981, Minibatch error= 0.2%
# 2019-07-17 21:31:00,149 Iter 182, Minibatch Loss= 0.0020, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:31:14,706 Iter 183, Minibatch Loss= 0.0091, Training Accuracy= 0.9986, Minibatch error= 0.1%
# 2019-07-17 21:31:29,733 Iter 184, Minibatch Loss= 0.1680, Training Accuracy= 0.9502, Minibatch error= 5.0%
# 2019-07-17 21:31:44,287 Iter 185, Minibatch Loss= 0.0073, Training Accuracy= 0.9992, Minibatch error= 0.1%
# 2019-07-17 21:31:58,915 Iter 186, Minibatch Loss= 0.0031, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:32:14,042 Iter 187, Minibatch Loss= 0.1618, Training Accuracy= 0.9566, Minibatch error= 4.3%
# 2019-07-17 21:32:28,584 Iter 188, Minibatch Loss= 0.0004, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:32:43,202 Iter 189, Minibatch Loss= 0.0106, Training Accuracy= 0.9990, Minibatch error= 0.1%
# 2019-07-17 21:32:57,864 Iter 190, Minibatch Loss= 0.0096, Training Accuracy= 0.9981, Minibatch error= 0.2%
# 2019-07-17 21:33:12,720 Iter 191, Minibatch Loss= 0.0000, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:33:12,721 Epoch 5, Average loss: 0.0269, learning rate: 0.4643
# 2019-07-17 21:33:31,493 Verification error= 0.4%, loss= 0.0161
# 2019-07-17 21:33:47,113 Iter 192, Minibatch Loss= 0.0248, Training Accuracy= 0.9930, Minibatch error= 0.7%
# 2019-07-17 21:34:01,724 Iter 193, Minibatch Loss= 0.0093, Training Accuracy= 0.9980, Minibatch error= 0.2%
# 2019-07-17 21:34:16,408 Iter 194, Minibatch Loss= 0.0007, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:34:31,052 Iter 195, Minibatch Loss= 0.0564, Training Accuracy= 0.9784, Minibatch error= 2.2%
# 2019-07-17 21:34:45,925 Iter 196, Minibatch Loss= 0.0502, Training Accuracy= 0.9893, Minibatch error= 1.1%
# 2019-07-17 21:35:00,476 Iter 197, Minibatch Loss= 0.0001, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:35:15,106 Iter 198, Minibatch Loss= 0.0054, Training Accuracy= 0.9983, Minibatch error= 0.2%
# 2019-07-17 21:35:30,157 Iter 199, Minibatch Loss= 0.1619, Training Accuracy= 0.9566, Minibatch error= 4.3%
# 2019-07-17 21:35:44,754 Iter 200, Minibatch Loss= 0.0033, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-17 21:35:59,258 Iter 201, Minibatch Loss= 0.0028, Training Accuracy= 0.9998, Minibatch error= 0.0%
# 2019-07-17 21:36:13,842 Iter 202, Minibatch Loss= 0.0131, Training Accuracy= 0.9986, Minibatch error= 0.1%
# 2019-07-17 21:36:28,833 Iter 203, Minibatch Loss= 0.0849, Training Accuracy= 0.9743, Minibatch error= 2.6%
# 2019-07-17 21:36:43,609 Iter 204, Minibatch Loss= 0.0063, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-17 21:36:58,229 Iter 205, Minibatch Loss= 0.0196, Training Accuracy= 0.9935, Minibatch error= 0.6%
# 2019-07-17 21:37:12,911 Iter 206, Minibatch Loss= 0.0077, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-17 21:37:27,767 Iter 207, Minibatch Loss= 0.0554, Training Accuracy= 0.9859, Minibatch error= 1.4%
# 2019-07-17 21:37:42,573 Iter 208, Minibatch Loss= 0.0039, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:37:57,402 Iter 209, Minibatch Loss= 0.0034, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:38:12,019 Iter 210, Minibatch Loss= 0.0000, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:38:27,122 Iter 211, Minibatch Loss= 0.1889, Training Accuracy= 0.9502, Minibatch error= 5.0%
# 2019-07-17 21:38:41,697 Iter 212, Minibatch Loss= 0.0155, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:38:56,515 Iter 213, Minibatch Loss= 0.0489, Training Accuracy= 0.9904, Minibatch error= 1.0%
# 2019-07-17 21:39:11,202 Iter 214, Minibatch Loss= 0.0148, Training Accuracy= 0.9955, Minibatch error= 0.5%
# 2019-07-17 21:39:25,853 Iter 215, Minibatch Loss= 0.0133, Training Accuracy= 0.9973, Minibatch error= 0.3%
# 2019-07-17 21:39:40,575 Iter 216, Minibatch Loss= 0.0071, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:39:55,085 Iter 217, Minibatch Loss= 0.0051, Training Accuracy= 0.9992, Minibatch error= 0.1%
# 2019-07-17 21:40:09,804 Iter 218, Minibatch Loss= 0.0058, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:40:24,616 Iter 219, Minibatch Loss= 0.0023, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:40:39,710 Iter 220, Minibatch Loss= 0.1771, Training Accuracy= 0.9502, Minibatch error= 5.0%
# 2019-07-17 21:40:54,275 Iter 221, Minibatch Loss= 0.0011, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:41:09,017 Iter 222, Minibatch Loss= 0.0094, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:41:23,784 Iter 223, Minibatch Loss= 0.0122, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-17 21:41:23,785 Epoch 6, Average loss: 0.0348, learning rate: 0.4411
# 2019-07-17 21:41:42,451 Verification error= 0.4%, loss= 0.0179
# 2019-07-17 21:41:58,124 Iter 224, Minibatch Loss= 0.0077, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-17 21:42:13,075 Iter 225, Minibatch Loss= 0.1647, Training Accuracy= 0.9566, Minibatch error= 4.3%
# 2019-07-17 21:42:27,603 Iter 226, Minibatch Loss= 0.0001, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:42:42,442 Iter 227, Minibatch Loss= 0.0128, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:42:57,620 Iter 228, Minibatch Loss= 0.0015, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:43:14,654 Iter 229, Minibatch Loss= 0.0094, Training Accuracy= 0.9986, Minibatch error= 0.1%
# 2019-07-17 21:43:30,866 Iter 230, Minibatch Loss= 0.0121, Training Accuracy= 0.9973, Minibatch error= 0.3%
# 2019-07-17 21:43:45,993 Iter 231, Minibatch Loss= 0.0026, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:44:02,457 Iter 232, Minibatch Loss= 0.0000, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:44:18,394 Iter 233, Minibatch Loss= 0.0046, Training Accuracy= 0.9992, Minibatch error= 0.1%
# 2019-07-17 21:44:34,528 Iter 234, Minibatch Loss= 0.0589, Training Accuracy= 0.9859, Minibatch error= 1.4%
# 2019-07-17 21:44:49,612 Iter 235, Minibatch Loss= 0.0058, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:45:04,826 Iter 236, Minibatch Loss= 0.0026, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-17 21:45:20,072 Iter 237, Minibatch Loss= 0.0366, Training Accuracy= 0.9904, Minibatch error= 1.0%
# 2019-07-17 21:45:35,397 Iter 238, Minibatch Loss= 0.0140, Training Accuracy= 0.9955, Minibatch error= 0.5%
# 2019-07-17 21:45:51,885 Iter 239, Minibatch Loss= 0.0089, Training Accuracy= 0.9980, Minibatch error= 0.2%
# 2019-07-17 21:46:06,884 Iter 240, Minibatch Loss= 0.0859, Training Accuracy= 0.9743, Minibatch error= 2.6%
# 2019-07-17 21:46:22,073 Iter 241, Minibatch Loss= 0.0026, Training Accuracy= 0.9998, Minibatch error= 0.0%
# 2019-07-17 21:46:37,012 Iter 242, Minibatch Loss= 0.0051, Training Accuracy= 0.9983, Minibatch error= 0.2%
# 2019-07-17 21:46:52,190 Iter 243, Minibatch Loss= 0.0002, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:47:07,262 Iter 244, Minibatch Loss= 0.0258, Training Accuracy= 0.9930, Minibatch error= 0.7%
# 2019-07-17 21:47:22,291 Iter 245, Minibatch Loss= 0.0483, Training Accuracy= 0.9893, Minibatch error= 1.1%
# 2019-07-17 21:47:37,420 Iter 246, Minibatch Loss= 0.0016, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:47:53,087 Iter 247, Minibatch Loss= 0.0533, Training Accuracy= 0.9784, Minibatch error= 2.2%
# 2019-07-17 21:48:08,409 Iter 248, Minibatch Loss= 0.0137, Training Accuracy= 0.9990, Minibatch error= 0.1%
# 2019-07-17 21:48:23,894 Iter 249, Minibatch Loss= 0.0060, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:48:38,963 Iter 250, Minibatch Loss= 0.0102, Training Accuracy= 0.9981, Minibatch error= 0.2%
# 2019-07-17 21:48:54,205 Iter 251, Minibatch Loss= 0.0195, Training Accuracy= 0.9935, Minibatch error= 0.6%
# 2019-07-17 21:49:09,400 Iter 252, Minibatch Loss= 0.0046, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:49:25,164 Iter 253, Minibatch Loss= 0.0123, Training Accuracy= 0.9973, Minibatch error= 0.3%
# 2019-07-17 21:49:40,497 Iter 254, Minibatch Loss= 0.0057, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-17 21:49:55,755 Iter 255, Minibatch Loss= 0.0457, Training Accuracy= 0.9893, Minibatch error= 1.1%
# 2019-07-17 21:49:55,756 Epoch 7, Average loss: 0.0228, learning rate: 0.4190
# 2019-07-17 21:50:14,892 Verification error= 0.4%, loss= 0.0151
# 2019-07-17 21:50:30,848 Iter 256, Minibatch Loss= 0.0017, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:50:45,821 Iter 257, Minibatch Loss= 0.0056, Training Accuracy= 0.9983, Minibatch error= 0.2%
# 2019-07-17 21:51:01,444 Iter 258, Minibatch Loss= 0.0042, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-17 21:51:16,720 Iter 259, Minibatch Loss= 0.0010, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:51:32,262 Iter 260, Minibatch Loss= 0.0049, Training Accuracy= 0.9992, Minibatch error= 0.1%
# 2019-07-17 21:51:48,101 Iter 261, Minibatch Loss= 0.0350, Training Accuracy= 0.9904, Minibatch error= 1.0%
# 2019-07-17 21:52:02,913 Iter 262, Minibatch Loss= 0.0196, Training Accuracy= 0.9935, Minibatch error= 0.6%
# 2019-07-17 21:52:18,510 Iter 263, Minibatch Loss= 0.0001, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:52:33,786 Iter 264, Minibatch Loss= 0.0089, Training Accuracy= 0.9980, Minibatch error= 0.2%
# 2019-07-17 21:52:49,113 Iter 265, Minibatch Loss= 0.0076, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:53:04,620 Iter 266, Minibatch Loss= 0.0555, Training Accuracy= 0.9859, Minibatch error= 1.4%
# 2019-07-17 21:53:20,044 Iter 267, Minibatch Loss= 0.0534, Training Accuracy= 0.9784, Minibatch error= 2.2%
# 2019-07-17 21:53:35,691 Iter 268, Minibatch Loss= 0.0001, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:53:51,749 Iter 269, Minibatch Loss= 0.0006, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:54:07,358 Iter 270, Minibatch Loss= 0.0116, Training Accuracy= 0.9990, Minibatch error= 0.1%
# 2019-07-17 21:54:22,955 Iter 271, Minibatch Loss= 0.0000, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:54:38,743 Iter 272, Minibatch Loss= 0.0019, Training Accuracy= 0.9998, Minibatch error= 0.0%
# 2019-07-17 21:54:56,558 Iter 273, Minibatch Loss= 0.0030, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:55:14,699 Iter 274, Minibatch Loss= 0.0039, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:55:29,627 Iter 275, Minibatch Loss= 0.0025, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-17 21:55:44,607 Iter 276, Minibatch Loss= 0.0831, Training Accuracy= 0.9743, Minibatch error= 2.6%
# 2019-07-17 21:56:00,214 Iter 277, Minibatch Loss= 0.1582, Training Accuracy= 0.9566, Minibatch error= 4.3%
# 2019-07-17 21:56:16,042 Iter 278, Minibatch Loss= 0.1509, Training Accuracy= 0.9502, Minibatch error= 5.0%
# 2019-07-17 21:56:33,703 Iter 279, Minibatch Loss= 0.0244, Training Accuracy= 0.9930, Minibatch error= 0.7%
# 2019-07-17 21:56:51,217 Iter 280, Minibatch Loss= 0.0122, Training Accuracy= 0.9986, Minibatch error= 0.1%
# 2019-07-17 21:57:08,322 Iter 281, Minibatch Loss= 0.0075, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 21:57:23,881 Iter 282, Minibatch Loss= 0.0129, Training Accuracy= 0.9955, Minibatch error= 0.5%
# 2019-07-17 21:57:39,142 Iter 283, Minibatch Loss= 0.0086, Training Accuracy= 0.9981, Minibatch error= 0.2%
# 2019-07-17 21:57:54,879 Iter 284, Minibatch Loss= 0.0074, Training Accuracy= 0.9990, Minibatch error= 0.1%
# 2019-07-17 21:58:11,171 Iter 285, Minibatch Loss= 0.0127, Training Accuracy= 0.9973, Minibatch error= 0.3%
# 2019-07-17 21:58:26,692 Iter 286, Minibatch Loss= 0.0024, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-17 21:58:42,123 Iter 287, Minibatch Loss= 0.0811, Training Accuracy= 0.9743, Minibatch error= 2.6%
# 2019-07-17 21:58:42,124 Epoch 8, Average loss: 0.0270, learning rate: 0.3981
# 2019-07-17 21:59:01,571 Verification error= 0.4%, loss= 0.0154
# 2019-07-17 21:59:18,358 Iter 288, Minibatch Loss= 0.0471, Training Accuracy= 0.9893, Minibatch error= 1.1%
# 2019-07-17 21:59:34,971 Iter 289, Minibatch Loss= 0.0050, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-17 21:59:52,297 Iter 290, Minibatch Loss= 0.0012, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 22:00:08,769 Iter 291, Minibatch Loss= 0.0049, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 22:00:23,878 Iter 292, Minibatch Loss= 0.0048, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-17 22:00:39,386 Iter 293, Minibatch Loss= 0.0016, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 22:00:56,745 Iter 294, Minibatch Loss= 0.0085, Training Accuracy= 0.9986, Minibatch error= 0.1%
# 2019-07-17 22:01:14,239 Iter 295, Minibatch Loss= 0.0000, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 22:01:32,803 Iter 296, Minibatch Loss= 0.1559, Training Accuracy= 0.9566, Minibatch error= 4.3%
# 2019-07-17 22:01:48,270 Iter 297, Minibatch Loss= 0.0001, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 22:02:03,848 Iter 298, Minibatch Loss= 0.0002, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 22:02:20,248 Iter 299, Minibatch Loss= 0.0061, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 22:02:37,889 Iter 300, Minibatch Loss= 0.0483, Training Accuracy= 0.9784, Minibatch error= 2.2%
# 2019-07-17 22:02:55,107 Iter 301, Minibatch Loss= 0.0097, Training Accuracy= 0.9980, Minibatch error= 0.2%
# 2019-07-17 22:03:10,639 Iter 302, Minibatch Loss= 0.0146, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 22:03:27,150 Iter 303, Minibatch Loss= 0.0047, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 22:03:43,260 Iter 304, Minibatch Loss= 0.0324, Training Accuracy= 0.9904, Minibatch error= 1.0%
# 2019-07-17 22:03:58,735 Iter 305, Minibatch Loss= 0.0017, Training Accuracy= 0.9998, Minibatch error= 0.0%
# 2019-07-17 22:04:14,201 Iter 306, Minibatch Loss= 0.0052, Training Accuracy= 0.9983, Minibatch error= 0.2%
# 2019-07-17 22:04:29,364 Iter 307, Minibatch Loss= 0.0120, Training Accuracy= 0.9955, Minibatch error= 0.5%
# 2019-07-17 22:04:45,787 Iter 308, Minibatch Loss= 0.0078, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 22:05:01,109 Iter 309, Minibatch Loss= 0.0051, Training Accuracy= 0.9992, Minibatch error= 0.1%
# 2019-07-17 22:05:16,708 Iter 310, Minibatch Loss= 0.0515, Training Accuracy= 0.9859, Minibatch error= 1.4%
# 2019-07-17 22:05:31,717 Iter 311, Minibatch Loss= 0.0085, Training Accuracy= 0.9981, Minibatch error= 0.2%
# 2019-07-17 22:05:47,268 Iter 312, Minibatch Loss= 0.0223, Training Accuracy= 0.9930, Minibatch error= 0.7%
# 2019-07-17 22:06:02,766 Iter 313, Minibatch Loss= 0.0004, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 22:06:18,404 Iter 314, Minibatch Loss= 0.0183, Training Accuracy= 0.9935, Minibatch error= 0.6%
# 2019-07-17 22:06:34,775 Iter 315, Minibatch Loss= 0.1545, Training Accuracy= 0.9502, Minibatch error= 5.0%
# 2019-07-17 22:06:49,841 Iter 316, Minibatch Loss= 0.0041, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-17 22:07:05,303 Iter 317, Minibatch Loss= 0.0194, Training Accuracy= 0.9935, Minibatch error= 0.6%
# 2019-07-17 22:07:20,465 Iter 318, Minibatch Loss= 0.0001, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 22:07:35,700 Iter 319, Minibatch Loss= 0.0169, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 22:07:35,701 Epoch 9, Average loss: 0.0232, learning rate: 0.3781
# 2019-07-17 22:07:54,724 Verification error= 0.4%, loss= 0.0155
# 2019-07-17 22:08:10,595 Iter 320, Minibatch Loss= 0.0102, Training Accuracy= 0.9981, Minibatch error= 0.2%
# 2019-07-17 22:08:26,600 Iter 321, Minibatch Loss= 0.0051, Training Accuracy= 0.9983, Minibatch error= 0.2%
# 2019-07-17 22:08:42,086 Iter 322, Minibatch Loss= 0.0043, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-17 22:08:59,051 Iter 323, Minibatch Loss= 0.1529, Training Accuracy= 0.9566, Minibatch error= 4.3%
# 2019-07-17 22:09:14,897 Iter 324, Minibatch Loss= 0.0008, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 22:09:30,209 Iter 325, Minibatch Loss= 0.0140, Training Accuracy= 0.9990, Minibatch error= 0.1%
# 2019-07-17 22:09:45,499 Iter 326, Minibatch Loss= 0.0001, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 22:10:00,571 Iter 327, Minibatch Loss= 0.0130, Training Accuracy= 0.9973, Minibatch error= 0.3%
# 2019-07-17 22:10:15,709 Iter 328, Minibatch Loss= 0.0028, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 22:10:30,788 Iter 329, Minibatch Loss= 0.0020, Training Accuracy= 0.9998, Minibatch error= 0.0%
# 2019-07-17 22:10:46,041 Iter 330, Minibatch Loss= 0.0116, Training Accuracy= 0.9955, Minibatch error= 0.5%
# 2019-07-17 22:11:00,944 Iter 331, Minibatch Loss= 0.0087, Training Accuracy= 0.9980, Minibatch error= 0.2%
# 2019-07-17 22:11:15,845 Iter 332, Minibatch Loss= 0.0046, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 22:11:30,739 Iter 333, Minibatch Loss= 0.0001, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 22:11:45,760 Iter 334, Minibatch Loss= 0.0097, Training Accuracy= 0.9986, Minibatch error= 0.1%
# 2019-07-17 22:12:00,573 Iter 335, Minibatch Loss= 0.0011, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 22:12:15,901 Iter 336, Minibatch Loss= 0.0042, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-17 22:12:31,045 Iter 337, Minibatch Loss= 0.0055, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 22:12:46,267 Iter 338, Minibatch Loss= 0.0515, Training Accuracy= 0.9784, Minibatch error= 2.2%
# 2019-07-17 22:13:01,343 Iter 339, Minibatch Loss= 0.0438, Training Accuracy= 0.9893, Minibatch error= 1.1%
# 2019-07-17 22:13:16,547 Iter 340, Minibatch Loss= 0.0313, Training Accuracy= 0.9904, Minibatch error= 1.0%
# 2019-07-17 22:13:31,460 Iter 341, Minibatch Loss= 0.0219, Training Accuracy= 0.9930, Minibatch error= 0.7%
# 2019-07-17 22:13:46,559 Iter 342, Minibatch Loss= 0.0027, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 22:14:01,908 Iter 343, Minibatch Loss= 0.1511, Training Accuracy= 0.9502, Minibatch error= 5.0%
# 2019-07-17 22:14:17,130 Iter 344, Minibatch Loss= 0.0799, Training Accuracy= 0.9743, Minibatch error= 2.6%
# 2019-07-17 22:14:32,384 Iter 345, Minibatch Loss= 0.0508, Training Accuracy= 0.9859, Minibatch error= 1.4%
# 2019-07-17 22:14:47,277 Iter 346, Minibatch Loss= 0.0033, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 22:15:02,528 Iter 347, Minibatch Loss= 0.0055, Training Accuracy= 0.9992, Minibatch error= 0.1%
# 2019-07-17 22:15:18,360 Iter 348, Minibatch Loss= 0.0491, Training Accuracy= 0.9784, Minibatch error= 2.2%
# 2019-07-17 22:15:33,940 Iter 349, Minibatch Loss= 0.1497, Training Accuracy= 0.9502, Minibatch error= 5.0%
# 2019-07-17 22:15:49,503 Iter 350, Minibatch Loss= 0.0355, Training Accuracy= 0.9904, Minibatch error= 1.0%
# 2019-07-17 22:16:04,694 Iter 351, Minibatch Loss= 0.0072, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-17 22:16:04,694 Epoch 10, Average loss: 0.0318, learning rate: 0.3592
# 2019-07-17 22:16:24,002 Verification error= 0.4%, loss= 0.0147
# 2019-07-17 22:16:40,057 Iter 352, Minibatch Loss= 0.0014, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 22:16:55,694 Iter 353, Minibatch Loss= 0.0022, Training Accuracy= 0.9998, Minibatch error= 0.0%
# 2019-07-17 22:17:10,864 Iter 354, Minibatch Loss= 0.0768, Training Accuracy= 0.9743, Minibatch error= 2.6%
# 2019-07-17 22:17:27,174 Iter 355, Minibatch Loss= 0.0454, Training Accuracy= 0.9893, Minibatch error= 1.1%
# 2019-07-17 22:17:43,471 Iter 356, Minibatch Loss= 0.0057, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 22:17:58,873 Iter 357, Minibatch Loss= 0.0001, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 22:18:14,127 Iter 358, Minibatch Loss= 0.0024, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 22:18:30,076 Iter 359, Minibatch Loss= 0.0093, Training Accuracy= 0.9986, Minibatch error= 0.1%
# 2019-07-17 22:18:47,182 Iter 360, Minibatch Loss= 0.0019, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 22:19:03,531 Iter 361, Minibatch Loss= 0.0024, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-17 22:19:18,770 Iter 362, Minibatch Loss= 0.0027, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 22:19:33,875 Iter 363, Minibatch Loss= 0.0028, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-17 22:19:48,961 Iter 364, Minibatch Loss= 0.0079, Training Accuracy= 0.9981, Minibatch error= 0.2%
# 2019-07-17 22:20:04,269 Iter 365, Minibatch Loss= 0.0052, Training Accuracy= 0.9983, Minibatch error= 0.2%
# 2019-07-17 22:20:19,893 Iter 366, Minibatch Loss= 0.0068, Training Accuracy= 0.9990, Minibatch error= 0.1%
# 2019-07-17 22:20:35,179 Iter 367, Minibatch Loss= 0.0127, Training Accuracy= 0.9973, Minibatch error= 0.3%
# 2019-07-17 22:20:50,577 Iter 368, Minibatch Loss= 0.0045, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 22:21:06,756 Iter 369, Minibatch Loss= 0.0473, Training Accuracy= 0.9859, Minibatch error= 1.4%
# 2019-07-17 22:21:23,195 Iter 370, Minibatch Loss= 0.0087, Training Accuracy= 0.9980, Minibatch error= 0.2%
# 2019-07-17 22:21:38,601 Iter 371, Minibatch Loss= 0.0110, Training Accuracy= 0.9955, Minibatch error= 0.5%
# 2019-07-17 22:21:54,054 Iter 372, Minibatch Loss= 0.1544, Training Accuracy= 0.9566, Minibatch error= 4.3%
# 2019-07-17 22:22:10,273 Iter 373, Minibatch Loss= 0.0263, Training Accuracy= 0.9930, Minibatch error= 0.7%
# 2019-07-17 22:22:26,309 Iter 374, Minibatch Loss= 0.0181, Training Accuracy= 0.9935, Minibatch error= 0.6%
# 2019-07-17 22:22:41,798 Iter 375, Minibatch Loss= 0.0001, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 22:22:57,031 Iter 376, Minibatch Loss= 0.0077, Training Accuracy= 0.9992, Minibatch error= 0.1%
# 2019-07-17 22:23:12,055 Iter 377, Minibatch Loss= 0.0008, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 22:23:28,488 Iter 378, Minibatch Loss= 0.0001, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 22:23:44,606 Iter 379, Minibatch Loss= 0.0118, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 22:24:00,709 Iter 380, Minibatch Loss= 0.0210, Training Accuracy= 0.9930, Minibatch error= 0.7%
# 2019-07-17 22:24:16,574 Iter 381, Minibatch Loss= 0.0093, Training Accuracy= 0.9986, Minibatch error= 0.1%
# 2019-07-17 22:24:32,422 Iter 382, Minibatch Loss= 0.0127, Training Accuracy= 0.9973, Minibatch error= 0.3%
# 2019-07-17 22:24:47,434 Iter 383, Minibatch Loss= 0.0172, Training Accuracy= 0.9935, Minibatch error= 0.6%
# 2019-07-17 22:24:47,435 Epoch 11, Average loss: 0.0179, learning rate: 0.3413
# 2019-07-17 22:25:06,381 Verification error= 0.4%, loss= 0.0139
# 2019-07-17 22:25:22,200 Iter 384, Minibatch Loss= 0.0001, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 22:25:37,522 Iter 385, Minibatch Loss= 0.0110, Training Accuracy= 0.9955, Minibatch error= 0.5%
# 2019-07-17 22:25:54,345 Iter 386, Minibatch Loss= 0.0001, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 22:26:10,874 Iter 387, Minibatch Loss= 0.0025, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-17 22:26:26,553 Iter 388, Minibatch Loss= 0.0049, Training Accuracy= 0.9983, Minibatch error= 0.2%
# 2019-07-17 22:26:42,040 Iter 389, Minibatch Loss= 0.0040, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 22:26:58,216 Iter 390, Minibatch Loss= 0.0033, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-17 22:27:14,189 Iter 391, Minibatch Loss= 0.0423, Training Accuracy= 0.9893, Minibatch error= 1.1%
# 2019-07-17 22:27:30,424 Iter 392, Minibatch Loss= 0.0476, Training Accuracy= 0.9859, Minibatch error= 1.4%
# 2019-07-17 22:27:46,394 Iter 393, Minibatch Loss= 0.1478, Training Accuracy= 0.9566, Minibatch error= 4.3%
# 2019-07-17 22:28:02,031 Iter 394, Minibatch Loss= 0.0132, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 22:28:17,470 Iter 395, Minibatch Loss= 0.0028, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 22:28:32,320 Iter 396, Minibatch Loss= 0.0085, Training Accuracy= 0.9980, Minibatch error= 0.2%
# 2019-07-17 22:28:47,436 Iter 397, Minibatch Loss= 0.0748, Training Accuracy= 0.9743, Minibatch error= 2.6%
# 2019-07-17 22:29:02,523 Iter 398, Minibatch Loss= 0.0120, Training Accuracy= 0.9990, Minibatch error= 0.1%
# 2019-07-17 22:29:18,348 Iter 399, Minibatch Loss= 0.0028, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 22:29:33,691 Iter 400, Minibatch Loss= 0.1389, Training Accuracy= 0.9502, Minibatch error= 5.0%
# 2019-07-17 22:29:48,912 Iter 401, Minibatch Loss= 0.0083, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 22:30:03,918 Iter 402, Minibatch Loss= 0.0026, Training Accuracy= 0.9998, Minibatch error= 0.0%
# 2019-07-17 22:30:19,045 Iter 403, Minibatch Loss= 0.0100, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 22:30:34,044 Iter 404, Minibatch Loss= 0.0012, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 22:30:49,261 Iter 405, Minibatch Loss= 0.0000, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 22:31:04,168 Iter 406, Minibatch Loss= 0.0082, Training Accuracy= 0.9981, Minibatch error= 0.2%
# 2019-07-17 22:31:19,083 Iter 407, Minibatch Loss= 0.0005, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 22:31:33,960 Iter 408, Minibatch Loss= 0.0038, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-17 22:31:49,113 Iter 409, Minibatch Loss= 0.0286, Training Accuracy= 0.9904, Minibatch error= 1.0%
# 2019-07-17 22:32:04,007 Iter 410, Minibatch Loss= 0.0459, Training Accuracy= 0.9784, Minibatch error= 2.2%
# 2019-07-17 22:32:18,958 Iter 411, Minibatch Loss= 0.0061, Training Accuracy= 0.9992, Minibatch error= 0.1%
# 2019-07-17 22:32:33,764 Iter 412, Minibatch Loss= 0.0001, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-17 22:32:48,613 Iter 413, Minibatch Loss= 0.0421, Training Accuracy= 0.9893, Minibatch error= 1.1%
# ...
# 2019-07-18 03:17:47,116 Iter 1459, Minibatch Loss= 0.0042, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:18:03,083 Iter 1460, Minibatch Loss= 0.0020, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:18:19,003 Iter 1461, Minibatch Loss= 0.0059, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:18:34,730 Iter 1462, Minibatch Loss= 0.0025, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-18 03:18:50,456 Iter 1463, Minibatch Loss= 0.0145, Training Accuracy= 0.9935, Minibatch error= 0.6%
# 2019-07-18 03:19:06,180 Iter 1464, Minibatch Loss= 0.0001, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:19:21,778 Iter 1465, Minibatch Loss= 0.0073, Training Accuracy= 0.9980, Minibatch error= 0.2%
# 2019-07-18 03:19:37,571 Iter 1466, Minibatch Loss= 0.0087, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:19:53,403 Iter 1467, Minibatch Loss= 0.0181, Training Accuracy= 0.9930, Minibatch error= 0.7%
# 2019-07-18 03:20:09,049 Iter 1468, Minibatch Loss= 0.0000, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:20:24,891 Iter 1469, Minibatch Loss= 0.0082, Training Accuracy= 0.9955, Minibatch error= 0.5%
# 2019-07-18 03:20:40,549 Iter 1470, Minibatch Loss= 0.0090, Training Accuracy= 0.9990, Minibatch error= 0.1%
# 2019-07-18 03:20:56,435 Iter 1471, Minibatch Loss= 0.0064, Training Accuracy= 0.9992, Minibatch error= 0.1%
# 2019-07-18 03:20:56,435 Epoch 45, Average loss: 0.0149, learning rate: 0.0597
# 2019-07-18 03:21:16,312 Verification error= 0.4%, loss= 0.0121
# 2019-07-18 03:21:33,299 Iter 1472, Minibatch Loss= 0.0017, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:21:49,072 Iter 1473, Minibatch Loss= 0.0662, Training Accuracy= 0.9743, Minibatch error= 2.6%
# 2019-07-18 03:22:05,067 Iter 1474, Minibatch Loss= 0.1251, Training Accuracy= 0.9566, Minibatch error= 4.3%
# 2019-07-18 03:22:20,710 Iter 1475, Minibatch Loss= 0.0041, Training Accuracy= 0.9983, Minibatch error= 0.2%
# 2019-07-18 03:22:36,376 Iter 1476, Minibatch Loss= 0.0057, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:22:51,932 Iter 1477, Minibatch Loss= 0.0001, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:23:07,740 Iter 1478, Minibatch Loss= 0.0061, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:23:23,370 Iter 1479, Minibatch Loss= 0.0142, Training Accuracy= 0.9973, Minibatch error= 0.3%
# 2019-07-18 03:23:39,142 Iter 1480, Minibatch Loss= 0.0034, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-18 03:23:54,854 Iter 1481, Minibatch Loss= 0.0246, Training Accuracy= 0.9904, Minibatch error= 1.0%
# 2019-07-18 03:24:10,482 Iter 1482, Minibatch Loss= 0.0079, Training Accuracy= 0.9981, Minibatch error= 0.2%
# 2019-07-18 03:24:26,276 Iter 1483, Minibatch Loss= 0.0091, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:24:42,063 Iter 1484, Minibatch Loss= 0.0145, Training Accuracy= 0.9935, Minibatch error= 0.6%
# 2019-07-18 03:24:58,049 Iter 1485, Minibatch Loss= 0.0406, Training Accuracy= 0.9859, Minibatch error= 1.4%
# 2019-07-18 03:25:13,758 Iter 1486, Minibatch Loss= 0.0074, Training Accuracy= 0.9980, Minibatch error= 0.2%
# 2019-07-18 03:25:29,570 Iter 1487, Minibatch Loss= 0.0035, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:25:45,361 Iter 1488, Minibatch Loss= 0.0096, Training Accuracy= 0.9986, Minibatch error= 0.1%
# 2019-07-18 03:26:01,104 Iter 1489, Minibatch Loss= 0.0022, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-18 03:26:16,599 Iter 1490, Minibatch Loss= 0.0024, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-18 03:26:32,422 Iter 1491, Minibatch Loss= 0.0021, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:26:48,087 Iter 1492, Minibatch Loss= 0.0175, Training Accuracy= 0.9930, Minibatch error= 0.7%
# 2019-07-18 03:27:03,784 Iter 1493, Minibatch Loss= 0.0001, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:27:19,681 Iter 1494, Minibatch Loss= 0.0343, Training Accuracy= 0.9784, Minibatch error= 2.2%
# 2019-07-18 03:27:35,233 Iter 1495, Minibatch Loss= 0.0016, Training Accuracy= 0.9998, Minibatch error= 0.0%
# 2019-07-18 03:27:50,965 Iter 1496, Minibatch Loss= 0.0043, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:28:06,991 Iter 1497, Minibatch Loss= 0.1120, Training Accuracy= 0.9502, Minibatch error= 5.0%
# 2019-07-18 03:28:22,807 Iter 1498, Minibatch Loss= 0.0010, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:28:38,656 Iter 1499, Minibatch Loss= 0.0382, Training Accuracy= 0.9893, Minibatch error= 1.1%
# 2019-07-18 03:28:54,391 Iter 1500, Minibatch Loss= 0.0073, Training Accuracy= 0.9980, Minibatch error= 0.2%
# 2019-07-18 03:29:10,227 Iter 1501, Minibatch Loss= 0.0144, Training Accuracy= 0.9935, Minibatch error= 0.6%
# 2019-07-18 03:29:26,008 Iter 1502, Minibatch Loss= 0.0026, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-18 03:29:41,700 Iter 1503, Minibatch Loss= 0.0075, Training Accuracy= 0.9981, Minibatch error= 0.2%
# 2019-07-18 03:29:41,700 Epoch 46, Average loss: 0.0198, learning rate: 0.0567
# 2019-07-18 03:30:01,556 Verification error= 0.4%, loss= 0.0123
# 2019-07-18 03:30:18,623 Iter 1504, Minibatch Loss= 0.0018, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:30:34,590 Iter 1505, Minibatch Loss= 0.0400, Training Accuracy= 0.9859, Minibatch error= 1.4%
# 2019-07-18 03:30:50,817 Iter 1506, Minibatch Loss= 0.1109, Training Accuracy= 0.9502, Minibatch error= 5.0%
# 2019-07-18 03:31:06,431 Iter 1507, Minibatch Loss= 0.0010, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:31:22,214 Iter 1508, Minibatch Loss= 0.0056, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:31:37,886 Iter 1509, Minibatch Loss= 0.0083, Training Accuracy= 0.9955, Minibatch error= 0.5%
# 2019-07-18 03:31:53,528 Iter 1510, Minibatch Loss= 0.0050, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:32:09,346 Iter 1511, Minibatch Loss= 0.0340, Training Accuracy= 0.9784, Minibatch error= 2.2%
# 2019-07-18 03:32:25,088 Iter 1512, Minibatch Loss= 0.0099, Training Accuracy= 0.9990, Minibatch error= 0.1%
# 2019-07-18 03:32:40,737 Iter 1513, Minibatch Loss= 0.0000, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:32:56,426 Iter 1514, Minibatch Loss= 0.0024, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:33:12,342 Iter 1515, Minibatch Loss= 0.0024, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-18 03:33:28,366 Iter 1516, Minibatch Loss= 0.1277, Training Accuracy= 0.9566, Minibatch error= 4.3%
# 2019-07-18 03:33:44,037 Iter 1517, Minibatch Loss= 0.0143, Training Accuracy= 0.9973, Minibatch error= 0.3%
# 2019-07-18 03:33:59,792 Iter 1518, Minibatch Loss= 0.0053, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:34:15,545 Iter 1519, Minibatch Loss= 0.0117, Training Accuracy= 0.9986, Minibatch error= 0.1%
# 2019-07-18 03:34:31,178 Iter 1520, Minibatch Loss= 0.0031, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-18 03:34:46,995 Iter 1521, Minibatch Loss= 0.0383, Training Accuracy= 0.9893, Minibatch error= 1.1%
# 2019-07-18 03:35:02,593 Iter 1522, Minibatch Loss= 0.0185, Training Accuracy= 0.9930, Minibatch error= 0.7%
# 2019-07-18 03:35:18,450 Iter 1523, Minibatch Loss= 0.0643, Training Accuracy= 0.9743, Minibatch error= 2.6%
# 2019-07-18 03:35:34,189 Iter 1524, Minibatch Loss= 0.0101, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:35:49,697 Iter 1525, Minibatch Loss= 0.0001, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:36:05,212 Iter 1526, Minibatch Loss= 0.0020, Training Accuracy= 0.9998, Minibatch error= 0.0%
# 2019-07-18 03:36:21,024 Iter 1527, Minibatch Loss= 0.0068, Training Accuracy= 0.9992, Minibatch error= 0.1%
# 2019-07-18 03:36:36,796 Iter 1528, Minibatch Loss= 0.0238, Training Accuracy= 0.9904, Minibatch error= 1.0%
# 2019-07-18 03:36:52,503 Iter 1529, Minibatch Loss= 0.0038, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:37:08,284 Iter 1530, Minibatch Loss= 0.0001, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:37:24,044 Iter 1531, Minibatch Loss= 0.0040, Training Accuracy= 0.9983, Minibatch error= 0.2%
# 2019-07-18 03:37:39,566 Iter 1532, Minibatch Loss= 0.0001, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:37:55,231 Iter 1533, Minibatch Loss= 0.0103, Training Accuracy= 0.9986, Minibatch error= 0.1%
# 2019-07-18 03:38:10,865 Iter 1534, Minibatch Loss= 0.0139, Training Accuracy= 0.9973, Minibatch error= 0.3%
# 2019-07-18 03:38:26,482 Iter 1535, Minibatch Loss= 0.0001, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:38:26,482 Epoch 47, Average loss: 0.0191, learning rate: 0.0538
# 2019-07-18 03:38:46,298 Verification error= 0.4%, loss= 0.0122
# 2019-07-18 03:39:03,372 Iter 1536, Minibatch Loss= 0.0340, Training Accuracy= 0.9784, Minibatch error= 2.2%
# 2019-07-18 03:39:19,231 Iter 1537, Minibatch Loss= 0.0073, Training Accuracy= 0.9981, Minibatch error= 0.2%
# 2019-07-18 03:39:34,828 Iter 1538, Minibatch Loss= 0.0036, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:39:50,588 Iter 1539, Minibatch Loss= 0.0040, Training Accuracy= 0.9983, Minibatch error= 0.2%
# 2019-07-18 03:40:06,173 Iter 1540, Minibatch Loss= 0.0009, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:40:22,146 Iter 1541, Minibatch Loss= 0.0653, Training Accuracy= 0.9743, Minibatch error= 2.6%
# 2019-07-18 03:40:37,781 Iter 1542, Minibatch Loss= 0.0025, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-18 03:40:53,771 Iter 1543, Minibatch Loss= 0.0410, Training Accuracy= 0.9859, Minibatch error= 1.4%
# 2019-07-18 03:41:09,406 Iter 1544, Minibatch Loss= 0.0144, Training Accuracy= 0.9935, Minibatch error= 0.6%
# 2019-07-18 03:41:25,212 Iter 1545, Minibatch Loss= 0.0234, Training Accuracy= 0.9904, Minibatch error= 1.0%
# 2019-07-18 03:41:40,915 Iter 1546, Minibatch Loss= 0.0024, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-18 03:41:56,628 Iter 1547, Minibatch Loss= 0.0066, Training Accuracy= 0.9992, Minibatch error= 0.1%
# 2019-07-18 03:42:12,138 Iter 1548, Minibatch Loss= 0.0091, Training Accuracy= 0.9990, Minibatch error= 0.1%
# 2019-07-18 03:42:27,911 Iter 1549, Minibatch Loss= 0.0082, Training Accuracy= 0.9955, Minibatch error= 0.5%
# 2019-07-18 03:42:43,935 Iter 1550, Minibatch Loss= 0.1285, Training Accuracy= 0.9566, Minibatch error= 4.3%
# 2019-07-18 03:42:59,559 Iter 1551, Minibatch Loss= 0.0190, Training Accuracy= 0.9930, Minibatch error= 0.7%
# 2019-07-18 03:43:15,427 Iter 1552, Minibatch Loss= 0.1090, Training Accuracy= 0.9502, Minibatch error= 5.0%
# 2019-07-18 03:43:31,289 Iter 1553, Minibatch Loss= 0.0068, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:43:47,093 Iter 1554, Minibatch Loss= 0.0103, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:44:02,715 Iter 1555, Minibatch Loss= 0.0021, Training Accuracy= 0.9998, Minibatch error= 0.0%
# 2019-07-18 03:44:18,476 Iter 1556, Minibatch Loss= 0.0073, Training Accuracy= 0.9980, Minibatch error= 0.2%
# 2019-07-18 03:44:34,357 Iter 1557, Minibatch Loss= 0.0001, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:44:50,119 Iter 1558, Minibatch Loss= 0.0046, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:45:05,896 Iter 1559, Minibatch Loss= 0.0030, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-18 03:45:21,525 Iter 1560, Minibatch Loss= 0.0019, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:45:37,361 Iter 1561, Minibatch Loss= 0.0381, Training Accuracy= 0.9893, Minibatch error= 1.1%
# 2019-07-18 03:45:52,895 Iter 1562, Minibatch Loss= 0.0048, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:46:08,516 Iter 1563, Minibatch Loss= 0.0024, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:46:25,139 Iter 1564, Minibatch Loss= 0.0018, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:46:40,961 Iter 1565, Minibatch Loss= 0.0039, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:46:56,667 Iter 1566, Minibatch Loss= 0.0071, Training Accuracy= 0.9981, Minibatch error= 0.2%
# 2019-07-18 03:47:12,216 Iter 1567, Minibatch Loss= 0.0065, Training Accuracy= 0.9992, Minibatch error= 0.1%
# 2019-07-18 03:47:12,216 Epoch 48, Average loss: 0.0192, learning rate: 0.0512
# 2019-07-18 03:47:32,054 Verification error= 0.4%, loss= 0.0122
# 2019-07-18 03:47:49,026 Iter 1568, Minibatch Loss= 0.0000, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:48:04,951 Iter 1569, Minibatch Loss= 0.0377, Training Accuracy= 0.9893, Minibatch error= 1.1%
# 2019-07-18 03:48:20,879 Iter 1570, Minibatch Loss= 0.0073, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:48:36,649 Iter 1571, Minibatch Loss= 0.0143, Training Accuracy= 0.9935, Minibatch error= 0.6%
# 2019-07-18 03:48:52,264 Iter 1572, Minibatch Loss= 0.0040, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:49:08,060 Iter 1573, Minibatch Loss= 0.0082, Training Accuracy= 0.9955, Minibatch error= 0.5%
# 2019-07-18 03:49:23,838 Iter 1574, Minibatch Loss= 0.0174, Training Accuracy= 0.9930, Minibatch error= 0.7%
# 2019-07-18 03:49:39,530 Iter 1575, Minibatch Loss= 0.0138, Training Accuracy= 0.9973, Minibatch error= 0.3%
# 2019-07-18 03:49:55,183 Iter 1576, Minibatch Loss= 0.0016, Training Accuracy= 0.9998, Minibatch error= 0.0%
# 2019-07-18 03:50:10,873 Iter 1577, Minibatch Loss= 0.0074, Training Accuracy= 0.9980, Minibatch error= 0.2%
# 2019-07-18 03:50:26,609 Iter 1578, Minibatch Loss= 0.0032, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:50:42,320 Iter 1579, Minibatch Loss= 0.0023, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-18 03:50:57,927 Iter 1580, Minibatch Loss= 0.0001, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:51:13,686 Iter 1581, Minibatch Loss= 0.0089, Training Accuracy= 0.9986, Minibatch error= 0.1%
# 2019-07-18 03:51:29,230 Iter 1582, Minibatch Loss= 0.0001, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:51:45,032 Iter 1583, Minibatch Loss= 0.0019, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:52:00,735 Iter 1584, Minibatch Loss= 0.0684, Training Accuracy= 0.9743, Minibatch error= 2.6%
# 2019-07-18 03:52:16,373 Iter 1585, Minibatch Loss= 0.0027, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-18 03:52:32,075 Iter 1586, Minibatch Loss= 0.0009, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:52:48,151 Iter 1587, Minibatch Loss= 0.0395, Training Accuracy= 0.9859, Minibatch error= 1.4%
# 2019-07-18 03:53:04,174 Iter 1588, Minibatch Loss= 0.1300, Training Accuracy= 0.9566, Minibatch error= 4.3%
# 2019-07-18 03:53:19,829 Iter 1589, Minibatch Loss= 0.0239, Training Accuracy= 0.9904, Minibatch error= 1.0%
# 2019-07-18 03:53:35,507 Iter 1590, Minibatch Loss= 0.0340, Training Accuracy= 0.9784, Minibatch error= 2.2%
# 2019-07-18 03:53:51,433 Iter 1591, Minibatch Loss= 0.0103, Training Accuracy= 0.9990, Minibatch error= 0.1%
# 2019-07-18 03:54:07,244 Iter 1592, Minibatch Loss= 0.0053, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:54:22,962 Iter 1593, Minibatch Loss= 0.0025, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2019-07-18 03:54:38,746 Iter 1594, Minibatch Loss= 0.0040, Training Accuracy= 0.9983, Minibatch error= 0.2%
# 2019-07-18 03:54:54,728 Iter 1595, Minibatch Loss= 0.1102, Training Accuracy= 0.9502, Minibatch error= 5.0%
# 2019-07-18 03:55:10,417 Iter 1596, Minibatch Loss= 0.0055, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:55:26,303 Iter 1597, Minibatch Loss= 0.0001, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:55:41,980 Iter 1598, Minibatch Loss= 0.0021, Training Accuracy= 0.9998, Minibatch error= 0.0%
# 2019-07-18 03:55:57,609 Iter 1599, Minibatch Loss= 0.0001, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2019-07-18 03:55:57,609 Epoch 49, Average loss: 0.0189, learning rate: 0.0486
# 2019-07-18 03:56:17,513 Verification error= 0.4%, loss= 0.0125
# 2019-07-18 03:56:18,934 Optimization Finished!

# %%
import tensorflow as tf
epochs = 50
acc=[]
acc_=[]
loss=[]
loss_=[]
lr=[]
lr_=[]

import glob
eventfile = glob.glob(output_path+'/*.yao')[0]

for event in tf.train.summary_iterator(eventfile):
#    for value in event.summary.value:
#        print(value.tag)
#        if value.HasField('simple_value'):
#            print(value.simple_value)
    for v in event.summary.value:
        if v.tag == 'accuracy':
            acc.append(v.simple_value)
        if v.tag == 'loss':
            loss.append(v.simple_value)
        if v.tag == 'learning_rate':
            lr.append(v.simple_value)

iter = np.arange(0, len(acc))
iter_=[]
epoch = np.arange(0, epochs)

for i in np.arange(0,len(acc),int(len(acc)/epochs)):
    acc_.append(np.mean(acc[i:i+int(len(acc)/epochs)]))
    loss_.append(np.mean(loss[i:i+int(len(loss)/epochs)]))
    lr_.append(np.mean(lr[i:i+int(len(lr)/epochs)]))
    iter_.append(np.mean(iter[i:i+int(len(iter)/epochs)]))

plt.figure()
plt.plot(iter, acc, lw=1, linestyle = '--')
plt.plot(iter_, acc_)
plt.xlabel('iterations')
plt.ylabel('accuracy')
plt.ylim([0.9,1])
plt.figure()
plt.plot(iter, loss, lw=1, linestyle = '--')
plt.plot(iter_, loss_)
plt.xlabel('iterations')
plt.ylabel('loss')
plt.ylim([0,0.2])
print('loss in the final epoch is '+ str(loss_[len(epoch)-1]))
plt.figure()
plt.plot(iter, lr, lw=1, linestyle = '--')
plt.plot(iter_, lr_)
plt.xlabel('iterations')
plt.ylabel('learning rate')
plt.ylim([0,1])
# Out:
# WARNING:tensorflow:From /home/yao/anaconda3/lib/python3.6/site-packages/tensorflow/python/summary/summary_iterator.py:68: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# 2019-07-18 09:28:28,150 From /home/yao/anaconda3/lib/python3.6/site-packages/tensorflow/python/summary/summary_iterator.py:68: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# loss in the final epoch is 0.01773728797536478
# (0, 1)

# %% [markdown]
# ### Test performance

# %%
#prepare test data
test_data = image_util.ImageDataProvider("./data_train_20190717/*.tif")
i=11 #number of images
x_test, y_test = test_data(i)

net = unet.Unet(layers=3, features_root=32, channels=1, n_class=2)
prediction = net.predict(output_path+"/model.ckpt", x_test)

print(x_test.shape)
print(y_test.shape)
print(prediction.shape)
# Out:
# Number of files used: 32
# Number of channels: 1
# Number of classes: 2
# 2019-07-18 09:26:03,583 Layers 3, features 32, filter size 3x3, pool size: 2x2
# WARNING:tensorflow:From /home/yao/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# 2019-07-18 09:26:03,664 From /home/yao/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/yao/.local/lib/python3.6/site-packages/tf_unet-0.1.2-py3.6.egg/tf_unet/layers.py:39: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# 2019-07-18 09:26:03,704 From /home/yao/.local/lib/python3.6/site-packages/tf_unet-0.1.2-py3.6.egg/tf_unet/layers.py:39: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /home/yao/anaconda3/lib/python3.6/site-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# 2019-07-18 09:26:05,166 From /home/yao/anaconda3/lib/python3.6/site-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50_LR0.6_D0.95_M0.2_data_train_20190717/model.ckpt
# 2019-07-18 09:26:05,175 Restoring parameters from ./trained_3layers_feature32_epoch50_LR0.6_D0.95_M0.2_data_train_20190717/model.ckpt
# 2019-07-18 09:26:05,268 Model restored from file: ./trained_3layers_feature32_epoch50_LR0.6_D0.95_M0.2_data_train_20190717/model.ckpt
# (11, 1000, 1000, 1)
# (11, 1000, 1000, 2)
# (11, 960, 960, 2)

# %%
from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, precision_score, recall_score, log_loss, f1_score, classification_report
from sklearn.metrics import roc_curve, auc, roc_auc_score, precision_recall_curve, average_precision_score, accuracy_score

#test_y = y_test[...,20:1020,20:1020,1].flatten()
test_y = y_test[...,20:980,20:980,1].flatten()
test_y_predict = prediction[...,1].flatten()
predict_max = max(test_y_predict)
test_y_predict = test_y_predict/predict_max

print(max(test_y))
print(max(test_y_predict))
print(test_y.shape)
print(test_y_predict.shape)

print(classification_report(test_y, (test_y_predict > 0.3)))
# Out:
# 1.0
# 1.0
# (10137600,)
# (10137600,)
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.99      0.99  10055878
#          1.0       0.36      0.73      0.48     81722
#
#    micro avg       0.99      0.99      0.99  10137600
#    macro avg       0.68      0.86      0.74  10137600
# weighted avg       0.99      0.99      0.99  10137600

# %%
print(classification_report(test_y, (test_y_predict > 0.2)))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.99      0.99  10055878
#          1.0       0.32      0.79      0.45     81722
#
#    micro avg       0.98      0.98      0.98  10137600
#    macro avg       0.66      0.89      0.72  10137600
# weighted avg       0.99      0.98      0.99  10137600

# %%
fpr, tpr, thresholds = roc_curve(test_y, test_y_predict)
roc_auc = auc(fpr, tpr)

plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange', lw=lw, label = 'ROC curve (area = %0.4f)' % roc_auc)
plt.plot([0, 1], [0, 1], color = 'navy', lw=lw, linestyle = '--')
plt.xlim([0,1])
plt.ylim([0,1])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc = 'lower right')
plt.show()
print('AUC = ',roc_auc)

precision, recall, thresholds = precision_recall_curve(test_y, test_y_predict)
AP = average_precision_score(test_y, test_y_predict)
plt.figure()
plt.plot(recall, precision, label = 'Average Precision (area = %0.4f)' % AP)
plt.plot([0, 1], [1, 0], color = 'navy', lw=lw, linestyle = '--')
plt.xlim([0,1])
plt.ylim([0,1])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.legend(loc = 'lower right')
plt.show()
print('AP = ',AP)
# Out:
# AUC =  0.9856732194205902
# AP =  0.4983979943112358

# %%
import scipy.io as sio
dict={
    "iter_":iter_,
    "acc_":acc_,
    "loss_":loss_,
    "lr_":lr_,
    "fprate":fpr, 
    "tprate":tpr,
    "recall":recall, 
    "precision":precision
}

sio.savemat('performance'+prediction_path[12:]+'.mat', dict)

# %% [markdown]
# ### prediction on frac and nonfrac on Ross ice shelf

# %%
#prepare test data
test_data = image_util.ImageDataProvider("./data_ross/*.tif")
i=2 #number of images
x_test, y_test = test_data(i)
print(x_test.shape)
print(y_test.shape)

prediction = net.predict(output_path+"/model.ckpt", x_test)
# Out:
# Number of files used: 2
# Number of channels: 1
# Number of classes: 2
# (2, 1000, 1000, 1)
# (2, 1000, 1000, 2)
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50_LR0.4_D0.95_M0.2/model.ckpt
# 2019-06-13 21:45:26,250 Restoring parameters from ./trained_3layers_feature32_epoch50_LR0.4_D0.95_M0.2/model.ckpt
# 2019-06-13 21:45:26,327 Model restored from file: ./trained_3layers_feature32_epoch50_LR0.4_D0.95_M0.2/model.ckpt

# %%
# display
i=1#sample index
fig, ax = plt.subplots(1, 3, sharex=True, sharey=True, figsize=(15,5))
ax[0].imshow(x_test[i,...,0], aspect="auto")
ax[1].imshow(y_test[i,...,1], aspect="auto")
mask = prediction[i,...,1] > 0.3
ax[2].imshow(mask, aspect="auto")
ax[0].set_title("Input")
ax[1].set_title("Ground truth")
ax[2].set_title("Prediction")
fig.tight_layout()

# %%
# save as image
img = util.combine_img_prediction(x_test, y_test, prediction)
util.save_image(img, prediction_path+"/prediction_ross.jpg")

# %% [markdown]
# ### prediction on sample images

# %%
#prepare test data
test_data = image_util.ImageDataProvider("./data_sample/*.tif")
i=4 #number of images
x_test, y_test = test_data(i)
print(x_test.shape)
print(y_test.shape)

prediction = net.predict(output_path+"/model.ckpt", x_test)
# Out:
# Number of files used: 4
# Number of channels: 1
# Number of classes: 2
# (4, 241, 241, 1)
# (4, 241, 241, 2)
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-08 04:26:35,559 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-08 04:26:35,788 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt

# %%
# display
i=2 #sample index
fig, ax = plt.subplots(1, 3, sharex=True, sharey=True, figsize=(12,5))
ax[0].imshow(x_test[i,...,0], aspect="auto")
ax[1].imshow(y_test[i,...,1], aspect="auto")
mask = prediction[i,...,1] > 0.1
ax[2].imshow(mask, aspect="auto")
ax[0].set_title("Input")
ax[1].set_title("Ground truth")
ax[2].set_title("Prediction")
fig.tight_layout()

# %%
img = util.combine_img_prediction(x_test, y_test, prediction)
util.save_image(img, prediction_path+"/prediction_sample.jpg")

# %% [markdown]
# ### Apply to Antarctica

# %%
#prepare test data
for i in range (1,37):
    for j in range (1,44):
        test_data = image_util.ImageDataProvider("./data_Antarctica/MOA209_125m_mask"+str(i)+"x"+str(j)+".tif")
        x_test, y_test = test_data(1) # 1 image
        x_test_ = x_test[0,...,0]
        if x_test_.sum()!=0:
            prediction = net.predict(output_path+"/model.ckpt", x_test)
       #    print(prediction.shape)
            prediction = prediction[0,...,1]
            prediction = prediction/predict_max #rescale with max of test data
            #scipy.io.savemat('./predict_Antarctica_epoch50/prediction.mat', mdict={"prediction"+str(i)+"x"+str(j): prediction})
            matplotlib.image.imsave("./predict_Antarctica"+prediction_path[12:]+"/prediction"+str(i)+"x"+str(j)+".tif", prediction, vmin = 0, vmax = 1)
# Out:
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:36:35,542 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:36:35,590 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:36:38,709 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:36:38,789 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:36:42,222 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:36:42,306 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:36:45,608 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:36:45,661 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:36:48,661 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:36:48,714 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:36:51,728 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:36:51,780 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:36:54,745 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:36:54,798 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:36:57,784 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:36:57,839 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:00,880 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:00,935 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:03,942 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:04,004 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:07,921 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:08,000 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:11,208 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:11,295 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:14,543 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:14,627 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:17,837 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:17,925 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:20,968 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:21,052 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:24,575 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:24,676 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:28,626 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:28,746 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:32,297 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:32,420 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:37,230 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:37,329 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:40,686 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:40,781 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:44,496 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:44,605 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:48,009 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:48,114 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:52,561 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:52,670 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:55,966 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:56,077 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:59,320 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:37:59,416 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:03,024 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:03,106 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:06,053 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:06,161 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:09,500 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:09,617 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:12,806 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:12,913 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:17,057 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:17,148 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:20,142 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:20,264 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:23,473 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:23,589 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:26,576 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:26,689 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:30,307 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:30,419 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:33,495 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:33,618 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:36,596 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:36,724 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:39,743 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:39,865 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:42,981 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:43,113 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:46,184 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:46,316 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:49,253 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:49,388 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:52,432 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:52,555 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:55,535 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:55,680 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:58,653 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:38:58,784 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:02,102 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:02,211 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:05,578 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:05,694 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:08,927 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:09,091 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:12,274 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:12,418 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:16,012 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:16,177 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:19,388 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:19,522 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:22,599 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:22,745 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:25,876 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:26,025 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:29,110 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:29,251 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:32,464 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:32,659 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:36,169 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:36,351 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:39,802 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:39,954 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:43,021 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:43,168 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:46,311 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:46,461 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:49,645 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:49,804 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:53,194 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:53,346 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# Number of files used: 1
# Number of channels: 1
# Number of classes: 2
# INFO:tensorflow:Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:56,461 Restoring parameters from ./trained_3layers_feature32_epoch50/model.ckpt
# 2019-05-27 13:39:56,613 Model restored from file: ./trained_3layers_feature32_epoch50/model.ckpt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-64c11fa4b4c4> in <module>
#       6         x_test_ = x_test[0,...,0]
#       7         if x_test_.sum()!=0:
# ----> 8             prediction = net.predict(output_path+"/model.ckpt", x_test)
#       9        #    print(prediction.shape)
#      10             prediction = prediction[0,...,1]
#
# ~/.local/lib/python3.6/site-packages/tf_unet-0.1.2-py3.6.egg/tf_unet/unet.py in predict(self, model_path, x_test)
#     275
#     276             y_dummy = np.empty((x_test.shape[0], x_test.shape[1], x_test.shape[2], self.n_class))
# --> 277             prediction = sess.run(self.predicter, feed_dict={self.x: x_test, self.y: y_dummy, self.keep_prob: 1.})
#     278
#     279         return prediction
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1332   def _do_call(self, fn, *args):
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#    1336       message = compat.as_text(e.message)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#    1321     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1405     return tf_session.TF_SessionRun_wrapper(
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#    1409   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
